# %%
import pandas as pd
import os
import requests
import time
import numpy as np

# %%
path="D:\\CDS513\\Assignment 1\\Data"
    
os.chdir(path)

# Read csv data file
# Data without feature standardization
df = pd.read_csv('steam-200k.csv', header=None)

# %%
df
# Out:
#                 0                           1         2      3  4
# 0       151603712  The Elder Scrolls V Skyrim  purchase    1.0  0
# 1       151603712  The Elder Scrolls V Skyrim      play  273.0  0
# 2       151603712                   Fallout 4  purchase    1.0  0
# 3       151603712                   Fallout 4      play   87.0  0
# 4       151603712                       Spore  purchase    1.0  0
# ...           ...                         ...       ...    ... ..
# 199995  128470551                 Titan Souls      play    1.5  0
# 199996  128470551  Grand Theft Auto Vice City  purchase    1.0  0
# 199997  128470551  Grand Theft Auto Vice City      play    1.5  0
# 199998  128470551                        RUSH  purchase    1.0  0
# 199999  128470551                        RUSH      play    1.4  0
#
# [200000 rows x 5 columns]

# %%
df.columns = [
    'User-id',
    'Game-title',
    'Mode',
    'Playtime',
    'misc'
]
df.set_index('User-id', inplace=True)
df
# Out:
#                            Game-title      Mode  Playtime  misc
# User-id
# 151603712  The Elder Scrolls V Skyrim  purchase       1.0     0
# 151603712  The Elder Scrolls V Skyrim      play     273.0     0
# 151603712                   Fallout 4  purchase       1.0     0
# 151603712                   Fallout 4      play      87.0     0
# 151603712                       Spore  purchase       1.0     0
# ...                               ...       ...       ...   ...
# 128470551                 Titan Souls      play       1.5     0
# 128470551  Grand Theft Auto Vice City  purchase       1.0     0
# 128470551  Grand Theft Auto Vice City      play       1.5     0
# 128470551                        RUSH  purchase       1.0     0
# 128470551                        RUSH      play       1.4     0
#
# [200000 rows x 4 columns]

# %%
df['Mode'].value_counts()
# Out:
# purchase    129511
# play         70489
# Name: Mode, dtype: int64

# %%
# Pivot the DataFrame to transform 'purchase' and 'play' modes into separate columns
pivot_df = df.pivot_table(index=['User-id', 'Game-title'], columns='Mode', values='Playtime', fill_value=0)

# Reset the index to turn multi-index into columns
pivot_df = pivot_df.reset_index()

# Rename columns for clarity
pivot_df.columns = ['User-id', 'Game-title', 'Playtime', 'Purchase']

# Display the transformed DataFrame
pivot_df.head()
# Out:
#    User-id             Game-title  Playtime  Purchase
# 0     5250            Alien Swarm       4.9         1
# 1     5250        Cities Skylines     144.0         1
# 2     5250         Counter-Strike       0.0         1
# 3     5250  Counter-Strike Source       0.0         1
# 4     5250          Day of Defeat       0.0         1

# %%
game_titles = pivot_df['Game-title'].unique().tolist()
test100=game_titles[1:2]

# %%
test100
# Out:
# ['Assetto Corsa']

# %%
np.count_nonzero(game_titles)
# Out:
# 5155

# %% [markdown]
# # Getting Genres for each title

# %%
# IGDB API endpoint for games
url = 'https://api.igdb.com/v4/games'
client_id = 'sxiuj4y04yliue4d66h7dkoxt3sjjf'
access_token = 'vbc6nonqwnvym37xdlzfa2df8sh07i'
headers = {
    'Client-ID': client_id,
    'Authorization': f'Bearer {access_token}',
    'Accept': 'application/json'
}

# %%
def search_games(titles, batch_size=600):
    # Prepare to collect genres
    genres_dict = {}

    # Process in batches to manage API request volume
    for i in range(0, len(titles), batch_size):
        batch_titles = titles[i:i+batch_size]
        # Constructing the body for multiple searches can be complex because IGDB API may not support multiple searches in one request.
        # Here we handle them one by one in a batch loop for demonstration.
        for title in batch_titles:
            body = f'search "{title}"; fields name, genres.name; limit 100;'
            response = requests.post(url, headers=headers, data=body)
            if response.status_code == 200:
                data = response.json()
                if data and 'genres' in data[0] and data[0]['genres']:
                    genres_dict[title] = data[0]['genres'][0]['name']
                else:
                    genres_dict[title] = 'Genre not found'
            else:
                print(f'API request failed with status code {response.status_code}')
            time.sleep(1)  # Sleep to respect API rate limit
            
    return genres_dict

# %%
genres_info = search_games(game_titles)
print(genres_info)
# Out:
# {'Alien Swarm': 'Shooter', 'Cities Skylines': 'Simulator', 'Counter-Strike': 'Shooter', 'Counter-Strike Source': 'Shooter', 'Day of Defeat': 'Shooter', 'Deathmatch Classic': 'Shooter', 'Deus Ex Human Revolution': 'Shooter', 'Dota 2': 'Strategy', 'Half-Life': 'Shooter', 'Half-Life 2': 'Shooter', 'Half-Life 2 Deathmatch': 'Shooter', 'Half-Life 2 Episode One': 'Shooter', 'Half-Life 2 Episode Two': 'Shooter', 'Half-Life 2 Lost Coast': 'Shooter', 'Half-Life Blue Shift': 'Shooter', 'Half-Life Opposing Force': 'Shooter', 'Portal': 'Real Time Strategy (RTS)', 'Portal 2': 'Shooter', 'Ricochet': 'Genre not found', 'Team Fortress 2': 'Shooter', 'Team Fortress Classic': 'Shooter', 'Age of Empires II HD Edition': 'Real Time Strategy (RTS)', 'Arma 2': 'Shooter', 'Arma 2 Operation Arrowhead': 'Shooter', 'Arma 2 Operation Arrowhead Beta (Obsolete)': 'Genre not found', 'Banished': 'Genre not found', 'Call of Duty Black Ops': 'Shooter', 'Call of Duty Black Ops - Multiplayer': 'Genre not found', 'Call of Duty Modern Warfare 2': 'Shooter', 'Call of Duty Modern Warfare 2 - Multiplayer': 'Genre not found', 'Call of Duty Modern Warfare 3': 'Shooter', 'Call of Duty Modern Warfare 3 - Multiplayer': 'Genre not found', 'Call of Duty World at War': 'Shooter', 'Counter-Strike Global Offensive': 'Shooter', 'Rise of Nations Extended Edition': 'Real Time Strategy (RTS)', 'The Stanley Parable': 'Adventure', 'Thief': 'Shooter', 'Thief - Ghost': 'Genre not found', 'Thief - Opportunist': 'Genre not found', 'Thief - Predator': 'Genre not found', 'Thief - The Bank Heist': 'Shooter', 'Thief 2': 'Shooter', 'Thief Deadly Shadows': 'Shooter', 'Thief Gold': 'Simulator', 'Total War ATTILA': 'Strategy', 'Worms Armageddon': 'Strategy', 'Age of Empires II HD The Forgotten': 'Real Time Strategy (RTS)', 'Alan Wake': 'Shooter', "Alan Wake's American Nightmare": 'Shooter', 'Audiosurf': 'Music', "Back to the Future Ep 1 - It's About Time": 'Point-and-click', 'Back to the Future Ep 2 - Get Tannen!': 'Point-and-click', 'Back to the Future Ep 3 - Citizen Brown': 'Point-and-click', 'Back to the Future Ep 4 - Double Visions': 'Point-and-click', 'Back to the Future Ep 5 - OUTATIME': 'Point-and-click', 'Borderlands 2': 'Shooter', 'Deus Ex Game of the Year Edition': 'Shooter', 'Deus Ex Human Revolution - The Missing Link': 'Shooter', 'Deus Ex Invisible War': 'Shooter', 'DiRT 3': 'Racing', 'DiRT 3 Complete Edition': 'Racing', 'DiRT Showdown': 'Racing', 'FTL Faster Than Light': 'Role-playing (RPG)', 'Far Cry 3': 'Shooter', 'Hector Ep 1': 'Point-and-click', 'Hector Ep 2': 'Point-and-click', 'Hector Ep 3': 'Point-and-click', 'Killer is Dead': "Hack and slash/Beat 'em up", 'L.A. Noire': 'Strategy', 'Left 4 Dead 2': 'Shooter', 'Max Payne 3': 'Shooter', 'Operation Flashpoint Dragon Rising': 'Shooter', 'Operation Flashpoint Red River': 'Shooter', 'Overlord': 'Role-playing (RPG)', 'Overlord II': 'Role-playing (RPG)', 'Overlord Raising Hell': 'Role-playing (RPG)', 'Poker Night at the Inventory': 'Sport', 'Puzzle Agent': 'Point-and-click', 'Puzzle Agent 2': 'Point-and-click', 'Rise of the Argonauts': 'Role-playing (RPG)', 'Sam & Max 301 The Penal Zone': 'Point-and-click', 'Sam & Max 302 The Tomb of Sammun-Mak': 'Point-and-click', "Sam & Max 303 They Stole Max's Brain!": 'Point-and-click', 'Sam & Max 304 Beyond the Alley of the Dolls': 'Point-and-click', 'Sam & Max 305 The City that Dares not Sleep': 'Point-and-click', 'Serious Sam 2': 'Shooter', 'Serious Sam 3 BFE': 'Shooter', 'Serious Sam Classic The First Encounter': 'Shooter', 'Serious Sam Classic The Second Encounter': 'Shooter', 'Serious Sam Classics Revolution': 'Shooter', 'Serious Sam Double D XXL': 'Shooter', 'Serious Sam HD The First Encounter': 'Shooter', 'Serious Sam The Random Encounter': 'Shooter', 'Skyrim High Resolution Texture Pack': 'Genre not found', 'The Elder Scrolls V Skyrim': 'Role-playing (RPG)', 'The Elder Scrolls V Skyrim - Dawnguard': 'Role-playing (RPG)', 'The Elder Scrolls V Skyrim - Dragonborn': 'Role-playing (RPG)',  ...

# %%
genres_df = pd.DataFrame.from_dict(genres_info, orient='index', columns=['Genre'])

genres_df.reset_index(inplace=True)

genres_df.rename(columns={'index': 'Game-title'}, inplace=True)

# %%
genres_df
# Out:
#                                              Game-title               Genre
# 0                                           Alien Swarm             Shooter
# 1                                       Cities Skylines           Simulator
# 2                                        Counter-Strike             Shooter
# 3                                 Counter-Strike Source             Shooter
# 4                                         Day of Defeat             Shooter
# ...                                                 ...                 ...
# 5150  Heroes Never Lose Professor Puzzler's Perplexi...              Puzzle
# 5151                                        Operation Z               Indie
# 5152                                        Retaliation           Adventure
# 5153                                           Abducted  Role-playing (RPG)
# 5154                                      SimpleRockets           Simulator
#
# [5155 rows x 2 columns]

# %%
# Concatenate with the existing DataFrame
combined_genres_df = pd.concat([combined_genres_df, genres_df], ignore_index=True)

# %%
combined_genres_df
# Out:
#                                              Game-title               Genre
# 0                                           Alien Swarm             Shooter
# 1                                       Cities Skylines           Simulator
# 2                                        Counter-Strike             Shooter
# 3                                 Counter-Strike Source             Shooter
# 4                                         Day of Defeat             Shooter
# ...                                                 ...                 ...
# 7150  Heroes Never Lose Professor Puzzler's Perplexi...              Puzzle
# 7151                                        Operation Z               Indie
# 7152                                        Retaliation           Adventure
# 7153                                           Abducted  Role-playing (RPG)
# 7154                                      SimpleRockets           Simulator
#
# [7155 rows x 2 columns]

# %%
combined_genres_df.to_csv('game_genres.csv')

# %%
merged_df = pd.merge(pivot_df, genres_df, on='Game-title', how='left')

# %%
merged_df
# Out:
#           User-id                    Game-title  Playtime  Purchase  \
# 0            5250                   Alien Swarm       4.9         1
# 1            5250               Cities Skylines     144.0         1
# 2            5250                Counter-Strike       0.0         1
# 3            5250         Counter-Strike Source       0.0         1
# 4            5250                 Day of Defeat       0.0         1
# ...           ...                           ...       ...       ...
# 128799  309626088  Age of Empires II HD Edition       6.7         1
# 128800  309812026  Counter-Strike Nexon Zombies       0.0         1
# 128801  309812026                     Robocraft       0.0         1
# 128802  309824202                        Dota 2       0.7         1
# 128803  309903146                        Dota 2       0.2         1
#
#                            Genre
# 0                        Shooter
# 1                      Simulator
# 2                        Shooter
# 3                        Shooter
# 4                        Shooter
# ...                          ...
# 128799  Real Time Strategy (RTS)
# 128800           Genre not found
# 128801                   Shooter
# 128802                  Strategy
# 128803                  Strategy
#
# [128804 rows x 5 columns]

# %%
cleaned_df = merged_df[merged_df['Genre'] != 'Genre not found'].drop(['Purchase'],axis=1)

# %%
cleaned_df
# Out:
#           User-id                    Game-title  Playtime  \
# 0            5250                   Alien Swarm       4.9
# 1            5250               Cities Skylines     144.0
# 2            5250                Counter-Strike       0.0
# 3            5250         Counter-Strike Source       0.0
# 4            5250                 Day of Defeat       0.0
# ...           ...                           ...       ...
# 128798  309554670             Mitos.is The Game       5.9
# 128799  309626088  Age of Empires II HD Edition       6.7
# 128801  309812026                     Robocraft       0.0
# 128802  309824202                        Dota 2       0.7
# 128803  309903146                        Dota 2       0.2
#
#                            Genre
# 0                        Shooter
# 1                      Simulator
# 2                        Shooter
# 3                        Shooter
# 4                        Shooter
# ...                          ...
# 128798  Real Time Strategy (RTS)
# 128799  Real Time Strategy (RTS)
# 128801                   Shooter
# 128802                  Strategy
# 128803                  Strategy
#
# [114716 rows x 4 columns]
