# %%
import pandas as pd
import os
import requests
import time
import numpy as np

# %%
path="D:\\CDS513\\Assignment 1\\Data"
    
os.chdir(path)

# Read csv data file
# Data without feature standardization
#df = pd.read_csv('steam-200k.csv', header=None)
df = pd.read_csv('Data_final_description.csv', header=None)

# %%
df.head()
# Out:
#            0                           1         2      3  4
# 0  151603712  The Elder Scrolls V Skyrim  purchase    1.0  0
# 1  151603712  The Elder Scrolls V Skyrim      play  273.0  0
# 2  151603712                   Fallout 4  purchase    1.0  0
# 3  151603712                   Fallout 4      play   87.0  0
# 4  151603712                       Spore  purchase    1.0  0

# %%
df.drop(columns =[4],inplace =True)

# %%
df.duplicated().sum()
# Out:
# 707

# %%
df.shape
# Out:
# (200000, 4)

# %%
df.drop_duplicates(inplace=True)

# %%
df.columns = [
    'User-id',
    'Game-title',
    'Mode',
    'Playtime'
]
df.set_index('User-id', inplace=True)

# %%
df.head()
# Out:
#                            Game-title      Mode  Playtime
# User-id
# 151603712  The Elder Scrolls V Skyrim  purchase       1.0
# 151603712  The Elder Scrolls V Skyrim      play     273.0
# 151603712                   Fallout 4  purchase       1.0
# 151603712                   Fallout 4      play      87.0
# 151603712                       Spore  purchase       1.0

# %%
df.nunique()
# Out:
# Game-title    5155
# Mode             2
# Playtime      1593
# dtype: int64

# %%
df['Mode'].value_counts()
# Out:
# purchase    128804
# play         70489
# Name: Mode, dtype: int64

# %%
df['Mode'].value_counts().plot(kind ='pie',autopct = '%1.1f%%', ylabel="")
# Out:
# <Axes: >

# %%
df['Game-title'].value_counts().head(10).plot(kind = 'pie',figsize =(10,6), autopct = '%1.1f%%', ylabel="")
# Out:
# <Axes: >

# %%
# Pivot the DataFrame to transform 'purchase' and 'play' modes into separate columns
pivot_df = df.pivot_table(index=['User-id', 'Game-title'], columns='Mode', values='Playtime', fill_value=0)

# Reset the index to turn multi-index into columns
pivot_df = pivot_df.reset_index()

# Rename columns for clarity
pivot_df.columns = ['User-id', 'Game-title', 'Playtime', 'Purchase']

# Display the transformed DataFrame
pivot_df.head()
# Out:
#    User-id             Game-title  Playtime  Purchase
# 0     5250            Alien Swarm       4.9         1
# 1     5250        Cities Skylines     144.0         1
# 2     5250         Counter-Strike       0.0         1
# 3     5250  Counter-Strike Source       0.0         1
# 4     5250          Day of Defeat       0.0         1

# %%
path="D:\\CDS513\\Assignment 1\\Data"
    
os.chdir(path)

# Read csv data file
# Data without feature standardization
pivot_df = pd.read_csv('Data_final_description.csv')
pivot_df
# Out:
#          User-id             Game-title               Genre  personal-rating  \
# 0           5250            Alien Swarm             Shooter                3
# 1         975449            Alien Swarm             Shooter                5
# 2        1950243            Alien Swarm             Shooter                3
# 3        2259650            Alien Swarm             Shooter                2
# 4        2753525            Alien Swarm             Shooter                2
# ...          ...                    ...                 ...              ...
# 42534  287824954        Close Your Eyes              Puzzle                5
# 42535  293303005            All Is Dust  Role-playing (RPG)                5
# 42536  300248088       Sigils of Elohim              Puzzle                5
# 42537  306839937  Secret Files Tunguska     Point-and-click                5
# 42538  307846753          SimpleRockets           Simulator                5
#
#                                              description
# 0      Alien Swarm is a game and Source SDK release f...
# 1      Alien Swarm is a game and Source SDK release f...
# 2      Alien Swarm is a game and Source SDK release f...
# 3      Alien Swarm is a game and Source SDK release f...
# 4      Alien Swarm is a game and Source SDK release f...
# ...                                                  ...
# 42534  Close Your Eyes is a puzzle horror game where ...
# 42535  Dust off the vacuum and tidy up with The Sims ...
# 42536  As if awakening from a deep sleep, you find yo...
# 42537  Unravel one of the greatest mysteries of our t...
# 42538  Design your own rocket ships. Blast off into s...
#
# [42539 rows x 5 columns]

# %%
game_titles = pivot_df['Game-title'].unique().tolist()

# %%
game_titles
# Out:
# ['Alien Swarm',
#  'Cities Skylines',
#  'Deus Ex Human Revolution',
#  'Portal 2',
#  'Age of Empires II HD Edition',
#  'Call of Duty Black Ops',
#  'Call of Duty Modern Warfare 2',
#  'Call of Duty Modern Warfare 3',
#  'Call of Duty World at War',
#  'Counter-Strike',
#  'Counter-Strike Global Offensive',
#  'Counter-Strike Source',
#  'Rise of Nations Extended Edition',
#  'Thief Deadly Shadows',
#  'Total War ATTILA',
#  'Audiosurf',
#  'Far Cry 3',
#  'Killer is Dead',
#  'Left 4 Dead 2',
#  'The Elder Scrolls V Skyrim',
#  'Torchlight II',
#  'XCOM Enemy Unknown',
#  'Counter-Strike Condition Zero',
#  'Half-Life 2 Episode One',
#  'Half-Life 2 Episode Two',
#  'Worms Reloaded',
#  '7 Days to Die',
#  'ARK Survival Evolved',
#  'Amnesia The Dark Descent',
#  'Armikrog',
#  'Batman Arkham Origins',
#  'BioShock Infinite',
#  'Borderlands',
#  'Borderlands 2',
#  'Broken Age',
#  'Brothers - A Tale of Two Sons',
#  'Bulletstorm',
#  'Castle Crashers',
#  'Chivalry Medieval Warfare',
#  'DARK SOULS II',
#  'DARK SOULS II Scholar of the First Sin',
#  'Dark Souls Prepare to Die Edition',
#  'Darksiders II',
#  'Dead Island',
#  'Dishonored',
#  'Divinity Original Sin',
#  'DmC Devil May Cry',
#  "Don't Starve",
#  'Dungeons of Dredmor',
#  'Dying Light',
#  'Endless Legend',
#  'FTL Faster Than Light',
#  'Fallout 4',
#  'Fallout New Vegas',
#  'Galactic Civilizations II Ultimate Edition',
#  "Garry's Mod",
#  'Gone Home',
#  'Hitman Absolution',
#  'Hotline Miami',
#  'Killing Floor 2',
#  'LEGO Batman 2',
#  'LEGO MARVEL Super Heroes',
#  'Legend of Grimrock',
#  'Little Inferno',
#  'METAL GEAR SOLID V GROUND ZEROES',
#  'METAL GEAR SOLID V THE PHANTOM PAIN',
#  'Machinarium',
#  'Magicka',
#  'Mark of the Ninja',
#  'Mass Effect 2',
#  'Max Payne 3',
#  'Metro 2033',
#  'Metro Last Light',
#  'Mortal Kombat X',
#  'Natural Selection 2',
#  'Orcs Must Die! 2',
#  'PAYDAY 2',
#  'Pillars of Eternity',
#  'Prison Architect',
#  'RAGE',
#  'Rocket League',
#  'Rogue Legacy',
#  'Rust',
#  'STAR WARS Knights of the Old Republic II The Sith Lords',
#  'Saints Row The Third',
#  'Sanctum',
#  'Serious Sam 3 BFE',
#  "Shadowrun Dragonfall - Director's Cut",
#  'Shadowrun Returns',
#  "Sid Meier's Civilization Beyond Earth",
#  "Sid Meier's Civilization V",
#  'Sonic Generations',
#  'Starbound',
#  'State of Decay',
#  'Team Fortress 2',
#  'Terraria',
#  'The Cave',
#  'The Forest',
#  'The Long Dark',
#  'The Walking Dead',
#  'The Witcher 2 Assassins of Kings Enhanced Edition',
#  'The Witcher 3 Wild Hunt',
#  'The Wolf Among Us',
#  'Thief',
#  "Tom Clancy's Splinter Cell Blacklist",
#  'Tomb Raider',
#  'Torchlight',
#  'Transformers Fall of Cybertron',
#  'Tropico 4',
#  'Unturned',
#  'Warhammer End Times - Vermintide',
#  'Wasteland 2',
#  'Half-Life 2',
#  'Alan Wake',
#  "Alan Wake's American Nightmare",
#  'BRINK',
#  'Battlefield Bad Company 2',
#  'Call of Duty Advanced Warfare',
#  'Call of Duty Black Ops II',
#  'Call of Duty Ghosts',
#  'Day of Defeat Source',
#  'DayZ',
#  'Duke Nukem Forever',
#  'Eufloria',
#  'F.E.A.R. 3',
#  'Front Mission Evolved',
#  'Half-Life Source',
#  'I Am Alive',
#  'Killing Floor',
#  'Mass Effect',
#  'Operation Flashpoint Red River',
#  'Osmos',
#  'Portal',
#  'Red Faction Guerrilla Steam Edition',
#  'Serious Sam HD The First Encounter',
#  'Sniper Elite V2',
#  'Spec Ops The Line',
#  'Synergy',
#  'Wolfenstein',
#  'F1 2014',
#  'Arma 2 Operation Arrowhead',
#  'Brothers in Arms Road to Hill 30',
#  'Company of Heroes Tales of Valor',
#  'Might & Magic Heroes VI',
#  'A.R.E.S.',
#  'Age of Chivalry',
#  "Assassin's Creed II",
#  "Assassin's Creed III",
#  "Assassin's Creed Revelations",
#  'Awesomenauts',
#  'BIT.TRIP RUNNER',
#  'Blocks That Matter',
#  'Braid',
#  "Brothers in Arms Hell's Highway",
#  'Burnout Paradise The Ultimate Box',
#  'Crysis 2 Maximum Edition',
#  'Crysis Warhead',
#  'DeathSpank',
#  'Defense Grid The Awakening',
#  'Deus Ex Human Revolution - The Missing Link',
#  'Dota 2',
#  'Empire Total War',
#  'Europa Universalis III',
#  'Faerie Solitaire',
#  'Frozen Synapse',
#  'Galcon Fusion',
#  'Gratuitous Space Battles',
#  'Half-Life 2 Deathmatch',
#  'Half-Life Blue Shift',
#  'Just Cause 2',
#  "King's Bounty Armored Princess",
#  "King's Bounty Crossworlds",
#  'McPixel',
#  "Mirror's Edge",
#  'Mount & Blade Warband',
#  'Napoleon Total War',
#  'Orcs Must Die!',
#  'PAYDAY The Heist',
#  'Plain Sight',
#  'Psychonauts',
#  'Renegade Ops',
#  'Revenge of the Titans',
#  'Rising Storm/Red Orchestra 2 Multiplayer',
#  'Rock of Ages',
#  'S.T.A.L.K.E.R. Shadow of Chernobyl',
#  'Serious Sam HD The Second Encounter',
#  'SpaceChem',
#  'Stacking',
#  'SteamWorld Dig',
#  'Super Meat Boy',
#  "Tales of Maj'Eyal",
#  'The Ball',
#  'The Binding of Isaac',
#  'The Path',
#  'The Secret of Monkey Island Special Edition',
#  'The Stanley Parable',
#  'The Typing of The Dead Overkill',
#  'Titan Quest Immortal Throne',
#  'Total War SHOGUN 2',
#  'VVVVVV',
#  'Vampire The Masquerade - Bloodlines',
#  'Zeno Clash',
#  'Day of Defeat',
#  'Half-Life',
#  'Half-Life Opposing Force',
#  "Sid Meier's Civilization III Complete",
#  'Sniper Elite',
#  'War Inc. Battlezone',
#  'Grand Theft Auto IV',
#  'Kingdom Rush',
#  'L.A. Noire',
#  'Sleeping Dogs',
#  'Always Sometimes Monsters',
#  'Blood Bowl Legendary Edition',
#  'Botanicula',
#  'Broforce',
#  'Car Mechanic Simulator 2014',
#  'CastleStorm',
#  'Cossacks II Napoleonic Wars',
#  'Elven Legacy',
#  'FlatOut 2',
#  'Game Dev Tycoon',
#  'Giana Sisters Twisted Dreams',
#  'Guacamelee! Gold Edition',
#  'Kerbal Space Program',
#  'King of Dragon Pass',
#  'LEGO Worlds',
#  'Magic 2014 ',
#  'Magic 2015',
#  'Magic Duels',
#  'Majesty 2',
#  'Men of War',
#  'Octodad Dadliest Catch',
#  'Pat & Mat',
#  'Rayman Legends',
#  'Red Orchestra Ostfront 41-45',
#  'Scribblenauts Unlimited',
#  "Sid Meier's Ace Patrol",
#  "Sid Meier's Civilization IV Colonization",
#  "Sid Meier's Pirates!",
#  "Sid Meier's Railroads!",
#  'Skulls of the Shogun',
#  'Space Hulk',
#  'Spintires',
#  'Supreme Commander',
#  'The Banner Saga',
#  'This War of Mine',
#  'Ticket to Ride',
#  'TowerFall Ascension',
#  'Trine 2',
#  'Ultimate General Gettysburg',
#  'Warhammer 40,000 Dawn of War II',
#  'Warhammer 40,000 Space Marine',
#  'World of Goo',
#  'Arma 3',
#  'Company of Heroes 2',
#  'Dungeon Defenders',
#  'Dungeon Defenders II',
#  'FINAL FANTASY VII',
#  'Planetary Annihilation',
#  'Planetary Annihilation TITANS',
#  'Plants vs. Zombies Game of the Year',
#  'Sins of a Solar Empire Trinity',
#  'Street Fighter IV',
#  'Supreme Commander 2',
#  'Unreal Tournament 3 Black Edition',
#  'World in Conflict Soviet Assault',
#  'Clicker Heroes',
#  'Darkest Dungeon',
#  'Dungeon of the Endless',
#  'Hero Academy',
#  'Path of Exile',
#  'Retro-Pixel Castles',
#  'Rocksmith 2014',
#  'Tap Tap Infinity',
#  'War of the Roses',
#  'DC Universe Online',
#  'DOOM II Hell on Earth',
#  'Bejeweled 2 Deluxe',
#  'BioShock 2',
#  'Cave Story+',
#  'Duke Nukem 3D Megaton Edition',
#  'GRID 2',
#  'LIMBO',
#  'Poker Night 2',
#  'Quake',
#  "Sid Meier's Civilization IV",
#  "Sid Meier's Civilization IV Warlords",
#  'South Park The Stick of Truth',
#  'Wolfenstein The New Order',
#  'Wolfenstein The Old Blood ',
#  'Call of Duty 4 Modern Warfare',
#  'F1 2011',
#  'Trials Evolution Gold Edition',
#  'Age of Wonders III',
#  'Black Mesa',
#  'Blacklight Retribution',
#  'Bloodline Champions',
#  'Call of Duty Black Ops II - Zombies',
#  'Dirty Bomb',
#  'H1Z1',
#  'Loadout',
#  'PlanetSide 2',
#  'Reign Of Kings',
#  'Sanctum 2',
#  'SpeedRunners',
#  'TERA',
#  'Warframe',
#  'ArcheAge',
#  'Arma 2',
#  'Robocraft',
#  'Section 8 Prejudice',
#  'X-COM Terror from the Deep',
#  'Far Cry 2',
#  'RaceRoom Racing Experience ',
#  'Ski Region Simulator',
#  'Fallout Tactics',
#  'Papers, Please',
#  'Wargame AirLand Battle',
#  'Wargame European Escalation',
#  'Call of Duty Advanced Warfare - Multiplayer',
#  'Total War ROME II - Emperor Edition',
#  'HAWKEN',
#  'IL-2 Sturmovik 1946',
#  'IL-2 Sturmovik Battle of Stalingrad',
#  'IL-2 Sturmovik Cliffs of Dover',
#  'Insurgency',
#  'Medieval II Total War',
#  'Craft The World',
#  'Dwarfs!?',
#  'Farm for your Life',
#  'Godus',
#  'Infinifactory',
#  'Mad Games Tycoon',
#  'Planetbase',
#  'Poly Bridge',
#  'Port Royale 3',
#  'RESCUE 2',
#  'RPG Maker VX Ace',
#  'Railroad Pioneer',
#  'The Escapists',
#  'Tropico 5',
#  'Windward',
#  'Borderlands The Pre-Sequel',
#  'Assetto Corsa',
#  'Crysis 2',
#  'DiRT 2',
#  'Euro Truck Simulator 2',
#  'F1 2010',
#  'SimCity 4 Deluxe',
#  'Warhammer 40,000 Dawn of War II - Chaos Rising',
#  'Enemy Territory Quake Wars',
#  'Bully Scholarship Edition',
#  'Grim Fandango Remastered',
#  "America's Army Proving Grounds",
#  'Dead Island Epidemic',
#  'Marvel Heroes 2015',
#  'Sins of a Dark Age',
#  'The Lord of the Rings Online',
#  'Darksiders',
#  'Crypt of the NecroDancer',
#  'Grim Dawn',
#  'MapleStory',
#  'Star Conflict',
#  'Stronghold 3',
#  'Besiege',
#  'DiRT 3',
#  'Divine Souls',
#  'FINAL FANTASY XIV A Realm Reborn',
#  'GunZ 2 The Second Duel',
#  'Lost Planet 3',
#  'RIFT',
#  'Remember Me',
#  'SolForge',
#  'The Bureau XCOM Declassified',
#  'Age of Empires III Complete Collection',
#  'Cities XL 2012',
#  'EVE Online',
#  'Elite Dangerous',
#  'Just Cause 3',
#  'Saints Row IV',
#  "Strike Suit Zero Director's Cut",
#  'Unreal Tournament Game of the Year Edition',
#  'Defiance',
#  'Fallout 3 - Game of the Year Edition',
#  'Grand Theft Auto Vice City',
#  'The Incredible Adventures of Van Helsing',
#  'DiRT Showdown',
#  'Angry Video Game Nerd Adventures',
#  'Anomaly 2',
#  'Ascendant',
#  'BattleBlock Theater',
#  'Ben There, Dan That!',
#  'Choice Chamber',
#  'Cook, Serve, Delicious!',
#  'DRAGON BALL XENOVERSE',
#  "Defender's Quest Valley of the Forgotten",
#  'Desktop Dungeons',
#  'Gauntlet ',
#  'Global Agenda',
#  'Guild of Dungeoneering',
#  'Hacknet',
#  'Hammerwatch',
#  'Hand Of Fate',
#  'Hero Siege',
#  'Legend of Dungeon Masters',
#  'Middle-earth Shadow of Mordor',
#  'Monday Night Combat',
#  'Need for Speed Undercover',
#  'Never Alone (Kisima Ingitchuna)',
#  'Nimble Quest',
#  'Nosgoth',
#  'Ori and the Blind Forest',
#  'Our Darker Purpose',
#  'Rampage Knights',
#  'Risk of Rain',
#  'Robot Roller-Derby Disco Dodgeball',
#  'Sacred Citadel',
#  'Spelunky',
#  'The Binding of Isaac Rebirth',
#  'The Mighty Quest For Epic Loot',
#  'The Walking Dead Season Two',
#  'Time Gentlemen, Please!',
#  'Volgarr the Viking',
#  'Warhammer 40,000 Dawn of War II  Retribution',
#  'Aliens Colonial Marines',
#  'Freedom Force',
#  'Titan Quest',
#  "Tom Clancy's Splinter Cell Double Agent",
#  'The Last Remnant',
#  'Half-Life 2 Lost Coast',
#  'Alpha Protocol',
#  'Anomaly Warzone Earth',
#  "Assassin's Creed",
#  'Car Mechanic Simulator 2015',
#  'Cogs',
#  'Command and Conquer Red Alert 3',
#  'Company of Heroes',
#  'Divinity II - The Dragon Knight Saga',
#  'Divinity Original Sin Enhanced Edition',
#  'Dragon Age II',
#  'Dragon Age Origins',
#  'Driver San Francisco',
#  'Earth 2160',
#  'Evil Genius',
#  'F1 2012',
#  'FINAL FANTASY XIII',
#  'Farming Simulator 15',
#  'Farming Simulator 2011',
#  'Farming Simulator 2013',
#  'GRID',
#  'GRID Autosport',
#  'Ghostbusters The Video Game',
#  'Hitman Blood Money',
#  'Impire',
#  'METAL GEAR RISING REVENGEANCE',
#  'Mad Max',
#  'Mafia II',
#  'Need for Speed Hot Pursuit',
#  'Next Car Game Wreckfest',
#  'Of Orcs And Men',
#  'Oil Rush',
#  'Overlord',
#  'Pirates of Black Cove',
#  'Prime World Defenders',
#  'Prototype',
#  'Quantum Conundrum',
#  'RACE 07',
#  'Shift 2 Unleashed',
#  'SpellForce 2 Gold Edition',
#  'Star Wars - Jedi Knight II Jedi Outcast',
#  'Stronghold 2',
#  'The Lord of the Rings War in the North',
#  'Tomb Raider Underworld',
#  'Train Simulator',
#  'Trine',
#  'Tropico 3 - Steam Special Edition',
#  'Evolve',
#  'Grey Goo',
#  'Space Engineers',
#  'Firefall',
#  'Alien Isolation',
#  'Amnesia A Machine for Pigs',
#  'BioShock',
#  'Crusader Kings II',
#  'Crysis',
#  'Darwinia',
#  'Dead Space',
#  'Dead Space 2',
#  'Dragon Age Origins - Ultimate Edition',
#  'Europa Universalis IV',
#  'F.E.A.R.',
#  'F.E.A.R. 2 Project Origin',
#  'Fate of the World',
#  'Franchise Hockey Manager 2014',
#  'Galactic Civilizations III',
#  'Game of Thrones - A Telltale Games Series',
#  'Homeworld Remastered Collection',
#  'Infested Planet',
#  'Medieval II Total War Kingdoms',
#  'ORION Prelude',
#  'Outlast',
#  'Plague Inc Evolved',
#  'Prey',
#  'R.U.S.E',
#  'RISK Factions',
#  "Sid Meier's Civilization IV Beyond the Sword",
#  'Sins of a Solar Empire Rebellion',
#  'Star Wars Knights of the Old Republic',
#  'Supreme Commander Forged Alliance',
#  'The Elder Scrolls IV Oblivion ',
#  'The Witcher Enhanced Edition',
#  'Wings of Prey',
#  'BRAINPIPE A Plunge to Unhumanity',
#  'Estranged Act I',
#  'Planets Under Attack',
#  'Krater',
#  'Batman Arkham Knight',
#  'Dungeon Defenders Eternity',
#  'Lords Of The Fallen',
#  'Pro Evolution Soccer 2014',
#  'Star Trek Online',
#  'Aliens vs. Predator',
#  'Blood Bowl 2',
#  'F1 2013',
#  'F1 2015',
#  'Hitman 2 Silent Assassin',
#  'Karate Master 2 Knock Down Blow',
#  'Lucius II',
#  'Mafia',
#  'Mount & Blade With Fire and Sword',
#  'NBA 2K13',
#  'Project CARS',
#  'Quantum of Solace',
#  'Railroad Tycoon 3',
#  'RollerCoaster Tycoon 3 Platinum!',
#  'Ryse Son of Rome',
#  'Sherlock Holmes Nemesis',
#  'Sherlock Holmes versus Jack the Ripper',
#  'Sniper Elite 3',
#  'Spore',
#  'Star Wars Jedi Knight Jedi Academy',
#  'Take On Helicopters',
#  'The Testament of Sherlock Holmes',
#  "Tom Clancy's Ghost Recon Future Soldier",
#  "Tom Clancy's Splinter Cell Conviction",
#  'Wargame Red Dragon',
#  'Watch_Dogs',
#  'Way of the Samurai 4',
#  'World of Guns Gun Disassembly',
#  'Blackguards',
#  'Dead State',
#  'Football Manager 2009',
#  'Football Manager 2013',
#  'Football Manager 2014',
#  'Football Manager 2015',
#  'Football Manager 2016',
#  'Silent Storm Sentinels',
#  'Insurgency Modern Infantry Combat',
#  "Back to the Future Ep 1 - It's About Time",
#  'Dead Rising 2',
#  'Double Dragon Neon',
#  'FlatOut Ultimate Carnage',
#  'Half-Life 2 Update',
#  'Hotline Miami 2 Wrong Number',
#  'Mortal Kombat Komplete Edition',
#  'One Finger Death Punch',
#  'Resident Evil Operation Raccoon City',
#  'Trials 2 Second Edition',
#  "Assassin's Creed Brotherhood",
#  "Baldur's Gate II Enhanced Edition",
#  'Bound By Flame',
#  'Company of Heroes Opposing Fronts',
#  'Dawn of Discovery',
#  'Dead Island Riptide',
#  'Deus Ex Game of the Year Edition',
#  'Disciples III Renaissance',
#  'Divinity II - Ego Draconis',
#  'Dungeon Siege III',
#  'Endless Space',
#  'Fable Anniversary',
#  'Fallen Enchantress',
#  'Grand Ages Rome',
#  'King Arthur - The Role-playing Wargame',
#  "King's Bounty The Legend",
#  'Kingdoms of Amalur Reckoning',
#  'Knights of Honor',
#  'Men of War Assault Squad',
#  'Might & Magic X - Legacy ',
#  'NBA 2K14',
#  'NBA 2K15',
#  'NBA 2K16',
#  "NOBUNAGA'S AMBITION Sphere of Influence",
#  'Pro Evolution Soccer 2015',
#  'Rebel Galaxy',
#  'Star Wars The Force Unleashed Ultimate Sith Edition',
#  'Starpoint Gemini 2',
#  'The Guild II Renaissance',
#  'The Settlers 7 Paths to a Kingdom - Gold Edition',
#  'Two Worlds Epic Edition',
#  'X3 Albion Prelude',
#  'X3 Terran Conflict',
#  'Xenonauts',
#  'Bunch Of Heroes',
#  'Altitude',
#  'Chime',
#  'Gunpoint',
#  'Magic The Gathering  Duels of the Planeswalkers 2012',
#  'Runaway A Road Adventure',
#  'S.T.A.L.K.E.R. Call of Pripyat',
#  'S.T.A.L.K.E.R. Clear Sky',
#  'Shadowgrounds',
#  'Shadowgrounds Survivor',
#  'Shattered Horizon',
#  'The Dream Machine',
#  'The Secret World',
#  'ArcaniA',
#  "Deus Ex Human Revolution - Director's Cut",
#  'Devilian',
#  'ENSLAVED Odyssey to the West Premium Edition',
#  'Far Cry 3 Blood Dragon',
#  'Free to Play',
#  'Homefront',
#  'Warhammer 40,000 Dawn of War  Winter Assault',
#  'Warhammer 40,000 Dawn of War - Game of the Year Edition',
#  'F.E.A.R. Extraction Point',
#  'F.E.A.R. Perseus Mandate',
#  'Painkiller Recurring Evil',
#  'Quake 4',
#  'Rocksmith',
#  'Thinking with Time Machine',
#  '4 Elements',
#  '9 Clues The Secret of Serpent Creek',
#  'Abyss The Wraiths of Eden',
#  'Alchemy Mysteries Prague Legends',
#  'Alice Madness Returns',
#  'And Yet It Moves',
#  'Anodyne',
#  'Antichamber',
#  'Atom Zombie Smasher ',
#  'Aura Fate of the Ages',
#  'Bastion',
#  'CID The Dummy',
#  'Cargo! - The quest for gravity',
#  'Clockwork Tales Of Glass and Ink',
#  'Contagion',
#  'Cryostasis',
#  'Deponia The Complete Journey',
#  'Eets',
#  'Ghost Master',
#  'Goat Simulator',
#  'Grand Theft Auto Episodes from Liberty City',
#  'Grim Legends The Forsaken Bride',
#  'Hector Ep 1',
#  'Hidden Object Bundle 4 in 1',
#  'Indigo Prophecy',
#  'Insanely Twisted Shadow Planet',
#  'Lara Croft and the Guardian of Light',
#  "MacGuffin's Curse",
#  'Monaco',
#  'Monkey Island 2 Special Edition',
#  'Nidhogg',
#  'Nightmares from the Deep 2 The Siren`s Call',
#  'Nightmares from the Deep The Cursed Heart',
#  'Obulis',
#  'Peggle Nights',
#  'Penumbra Black Plague',
#  'Penumbra Overture',
#  'Poker Night at the Inventory',
#  'Puzzle Agent',
#  'Puzzle Agent 2',
#  'Puzzler World 2',
#  'Resident Evil 5 / Biohazard 5',
#  'Rocketbirds Hardboiled Chicken',
#  'Saints Row 2',
#  'Sam & Max 101 Culture Shock',
#  'Sam & Max 104 Abe Lincoln Must Die!',
#  'Sam & Max 105 Reality 2.0',
#  'Sam & Max 106 Bright Side of the Moon',
#  'Shatter',
#  'Shoppe Keep',
#  'Singularity',
#  'Sinister City',
#  'Surgeon Simulator',
#  'Tales of Monkey Island Chapter 1 - Launch of the Screaming Narwhal',
#  'Tales of Monkey Island Chapter 2 - The Siege of Spinner Cay ',
#  'Tales of Monkey Island Chapter 3 - Lair of the Leviathan ',
#  'Tales of Monkey Island Chapter 4 - The Trial and Execution of Guybrush Threepwood ',
#  'Tales of Monkey Island Chapter 5 - Rise of the Pirate God',
#  'The Book of Unwritten Tales',
#  'The Elder Scrolls III Morrowind',
#  'The Jackbox Party Pack',
#  'The Maw',
#  'The Movies',
#  'The Tiny Bang Story',
#  'TrackMania Stadium',
#  'Vessel',
#  'Windosill',
#  'Worms Clan Wars',
#  'ibb & obb',
#  'Alien Breed Impact',
#  'Anoxemia',
#  'BEEP',
#  'Beatbuddy Tale of the Guardians',
#  'Bionic Dues',
#  'Blockstorm',
#  'Canyon Capers',
#  'Card Hunter',
#  'Chaos on Deponia',
#  'Chip',
#  'Coffin Dodgers',
#  'Coin Crypt',
#  'Costume Quest',
#  'Dino D-Day',
#  'Divinity Dragon Commander',
#  "Divinity II Developer's Cut",
#  'Dust An Elysian Tail',
#  'Dustforce',
#  'Electronic Super Joy',
#  'Enemy Mind',
#  'Fallen Enchantress Legendary Heroes',
#  'Fearless Fantasy',
#  'Freedom Planet',
#  'Goodbye Deponia',
#  'Guardians of Middle-earth',
#  'Gun Monkeys',
#  'Guns of Icarus Online',
#  'Hard Reset',
#  'Heavy Fire Afghanistan',
#  'Humanity Asset',
#  'Ionball 2  Ionstorm',
#  'Ironclad Tactics',
#  'Kidnapped',
#  'LUFTRAUSERS',
#  'Lucius',
#  'MURDERED SOUL SUSPECT',
#  'Magic The Gathering - Duels of the Planeswalkers',
#  'Magic The Gathering - Duels of the Planeswalkers 2013',
#  'Magicka Wizard Wars',
#  'Mercenary Kings',
#  'Might & Magic Duel of Champions',
#  'Moonrise',
#  'No More Room in Hell',
#  'Not The Robots',
#  'Nux',
#  'Outland',
#  'Overcast - Walden and the Werewolf',
#  'Painkiller Hell & Damnation',
#  'Particula',
#  'Pixel Piracy',
#  'Pixel Puzzles Japan',
#  'Primal Carnage Extinction',
#  'QuestRun',
#  'Ravaged Zombie Apocalypse',
#  'Red Faction Armageddon',
#  'Relic Hunters Zero',
#  'Risen',
#  'Robot Rescue Revolution',
#  'SUPER DISTRO',
#  'Screencheat',
#  'Shadow Warrior',
#  'Shadow Warrior Classic Redux',
#  'Shank 2',
#  'Sir, You Are Being Hunted',
#  'Skullgirls',
#  'Skyborn',
#  'Smashball',
#  'Sniper Elite Nazi Zombie Army 2',
#  'Sonic & All-Stars Racing Transformed',
#  'Strike Suit Zero',
#  'Syberia',
#  'System Shock 2',
#  'Talisman Digital Edition',
#  'The Darkness II',
#  'The Incredible Adventures of Van Helsing II',
#  'Tower of Guns',
#  'Two Worlds II',
#  'Worms Revolution',
#  'X-Blades',
#  'Zero Gear',
#  'Darkspore',
#  'Demigod',
#  'Dungeons & Dragons Chronicles of Mystara',
#  'PROTOTYPE 2',
#  'Sword Coast Legends',
#  'Ultra Street Fighter IV',
#  'Batman Arkham Asylum',
#  'Command and Conquer Red Alert 3 - Uprising',
#  'Just Cause',
#  'Absolute Drift',
#  'Among the Sleep',
#  'Grow Home',
#  'Layers of Fear',
#  'SOMA',
#  'The Showdown Effect',
#  'The Vanishing of Ethan Carter',
#  'Analogue A Hate Story',
#  'Blood Bowl Chaos Edition',
#  'Democracy 3',
#  'Jade Empire Special Edition',
#  'Reus',
#  'Space Pirates and Zombies',
#  'Spacebase DF-9',
#  'X-COM UFO Defense',
#  'Panzar',
#  'Styx Master of Shadows',
#  'Warhammer 40,000 Dawn of War  Dark Crusade',
#  'Warhammer 40,000 Dawn of War  Soulstorm',
#  'Heroes of Might & Magic III - HD Edition',
#  'Heroes of Might & Magic V',
#  'The Talos Principle',
#  'GALAK-Z',
#  'Operation Flashpoint Dragon Rising',
#  'Street Fighter X Tekken',
#  'ToCA Race Driver 3',
#  'Lost Planet Extreme Condition',
#  'Batman Arkham City',
#  'Doctor Who The Eternity Clock',
#  'GRAV',
#  'LEGO The Lord of the Rings',
#  'Ziggurat',
#  'Star Wars Republic Commando',
#  "Assassin's Creed IV Black Flag",
#  'DeathSpank Thongs Of Virtue',
#  'Legend of Grimrock 2',
#  'Mega Man Legacy Collection',
#  'Metro 2033 Redux',
#  'Overlord II',
#  'The Baconing',
#  'War for the Overworld',
#  'Gotham City Impostors',
#  'HELLDIVERS',
#  'Heroes & Generals',
#  'Resident Evil 6 / Biohazard 6',
#  'Warhammer Online Age of Reckoning',
#  'Sleeping Dogs Definitive Edition',
#  'HuniePop',
#  'Ironcast',
#  'Puzzle Quest',
#  "Recettear An Item Shop's Tale",
#  'Tales from the Borderlands',
#  'The Swindle',
#  'Panzer Corps',
#  'POSTAL 2',
#  'Arma 2 Private Military Company',
#  'Artemis Spaceship Bridge Simulator',
#  'DEFCON',
#  'Door Kickers',
#  'Offworld Trading Company',
#  'SPACECOM',
#  'The Swapper',
#  'Transistor',
#  'A Game of Thrones - Genesis',
#  'AdVenture Capitalist',
#  'Age of Wonders Shadow Magic',
#  'Crusader Kings Complete',
#  'Everlasting Summer',
#  'Fractured Space',
#  'Guild Wars Trilogy',
#  'Magical Diary',
#  'Neverwinter',
#  'Perpetuum',
#  'Star Trek D-A-C',
#  'Stellar Impact',
#  'Stronghold Kingdoms',
#  'Sword of the Stars Complete Collection',
#  'Sword of the Stars II Enhanced Edition',
#  'Time Clickers',
#  "Broken Sword 5 - the Serpent's Curse",
#  'Stronghold Crusader 2',
#  'Blur',
#  'Home',
#  'Mini Metro',
#  'Multiwinia',
#  'PixelJunk Shooter Ultimate',
#  'Reassembly',
#  'Zombie Panic Source',
#  'Deponia',
#  'Metro Last Light Redux',
#  'Football Manager 2010',
#  'Football Manager 2011',
#  'Football Manager 2012',
#  'Lost Planet 2',
#  'Universe Sandbox',
#  'Betrayer',
#  'Call of Juarez Bound in Blood',
#  'Nether',
#  'Shattered Union',
#  'Fable - The Lost Chapters',
#  'The Cat Lady',
#  'Counter-Strike Condition Zero Deleted Scenes',
#  'Desperados - Wanted Dead or Alive',
#  'Fable III',
#  "Oddworld Abe's Exoddus",
#  'Blades of Time',
#  'Deadpool',
#  'Sakura Spirit',
#  'Sonic Adventure DX',
#  'Thomas Was Alone',
#  'theHunter',
#  'FINAL FANTASY III',
#  'Jamestown',
#  'Lethal League',
#  'Gems of War',
#  'Marvel Puzzle Quest',
#  'ACE COMBAT ASSAULT HORIZON Enhanced Edition',
#  'Cry of Fear',
#  'Grand Theft Auto San Andreas',
#  'Medal of Honor Airborne',
#  'Rayman Origins',
#  'Road Redemption',
#  'Silent Hill Homecoming',
#  'Subnautica',
#  'THE KING OF FIGHTERS XIII STEAM EDITION',
#  'Test Drive Unlimited 2',
#  'The Four Kings Casino and Slots',
#  "Tom Clancy's Splinter Cell Chaos Theory",
#  "Tony Hawk's Pro Skater HD",
#  'Tropico 3 Absolute Power',
#  'Virtua Tennis 4',
#  'resident evil 4 / biohazard 4',
#  'Angels Fall First',
#  'Men of War Assault Squad 2',
#  'Project Zomboid',
#  'The Stomping Land',
#  'Verdun',
#  'Defense Grid 2',
#  'Age of Conan Rise of the Godslayer',
#  'Buccaneer The Pursuit of Infamy',
#  'Champions Online',
#  'Command and Conquer 4 Tiberian Twilight',
#  'Cosmonautica',
#  'DUNGEONS - Steam Special Edition',
#  'Dungeons & Dragons Online',
#  'Greed Corp',
#  'Invisible, Inc.',
#  'Leviathan Warships',
#  'Mordheim City of the Damned',
#  'Rome Total War',
#  'Space Hulk Ascension',
#  'Spore Creepy & Cute Parts Pack',
#  'Spore Galactic Adventures',
#  'StarDrive',
#  'StarDrive 2',
#  'Stranded Deep',
#  'The Masterplan',
#  'The Settlers 7 Paths to a Kingdom',
#  "Tom Clancy's H.A.W.X.",
#  'Age of Mythology Extended Edition',
#  'Aliens versus Predator Classic 2000',
#  'Flight Control HD',
#  'Renowned Explorers International Society',
#  'Sheltered',
#  'Star Wars - Battlefront II',
#  'The Curious Expedition',
#  'Dragon Nest',
#  'Dynasty Warriors 8 - Empires',
#  'From Dust',
#  'RollerCoaster Tycoon Deluxe',
#  'Capsized',
#  'Thief 2',
#  'Castlevania Lords of Shadow 2',
#  'Divekick',
#  'Tribes Ascend',
#  'Creativerse',
#  'TrackMania United',
#  'Afterfall InSanity Extended Edition',
#  'Aperture Tag The Paint Gun Testing Initiative',
#  'Beat Hazard',
#  'BloodRayne',
#  'BloodRayne 2',
#  'Carmageddon 2 Carpocalypse Now',
#  'Carmageddon Max Pack',
#  "Command and Conquer 3 Kane's Wrath",
#  'Cthulhu Saves the World ',
#  'Death Rally',
#  'Devil May Cry 4',
#  'DiRT',
#  'Fallout 2',
#  'Jagged Alliance 2 - Wildfire ',
#  'Midnight Club II',
#  'Post Apocalyptic Mayhem',
#  'Space Empires IV Deluxe',
#  'Unreal Tournament 2004',
#  'Gish',
#  'NARUTO SHIPPUDEN Ultimate Ninja STORM 3 Full Burst',
#  'Sol Survivor',
#  'Tower Wars',
#  'Towns',
#  'WAKFU',
#  'iBomber Defense',
#  'Realm of the Mad God',
#  'Cities in Motion',
#  'Harvest Massive Encounter',
#  'Nation Red',
#  'OTTTD',
#  'Peggle Extreme',
#  'Shoot Many Robots',
#  'Space Trader Merchant Marine',
#  'Swords and Soldiers HD',
#  ...]

# %%
np.count_nonzero(game_titles)
# Out:
# 2611

# %% [markdown]
# # Getting Additional Info for each Game-title

# %%
# IGDB API endpoint for games
url = 'https://api.igdb.com/v4/games'
client_id = 'sxiuj4y04yliue4d66h7dkoxt3sjjf'
access_token = '0wfjgbdpwg7qod7wx13mvf1afqqqcw'
headers = {
    'Client-ID': client_id,
    'Authorization': f'Bearer {access_token}',
    'Accept': 'application/json'
}

# %%
def search_games(titles, batch_size=600):
    # Prepare to collect genres and descriptions
    genres_dict = {}

    # Process in batches to manage API request volume
    for i in range(0, len(titles), batch_size):
        batch_titles = titles[i:i+batch_size]
        # Constructing the body for multiple searches can be complex because IGDB API may not support multiple searches in one request.
        # Here we handle them one by one in a batch loop for demonstration.
        for title in batch_titles:
            body = f'search "{title}"; fields name, genres.name, summary; limit 100;'
            response = requests.post(url, headers=headers, data=body)
            if response.status_code == 200:
                data = response.json()
                if data:
                    game_info = {
                        'genre': data[0]['genres'][0]['name'] if 'genres' in data[0] and data[0]['genres'] else 'Genre not found',
                        'summary': data[0]['summary'] if 'summary' in data[0] else 'Summary not found'
                    }
                    genres_dict[title] = game_info
                else:
                    genres_dict[title] = {'genre': 'Genre not found', 'summary': 'Summary not found'}
            else:
                print(f'API request failed with status code {response.status_code}')
            time.sleep(1)  # Sleep to respect API rate limit
            
    return genres_dict

# %%
def search_games(titles, batch_size=600):
    game_info_list = []
    
    for i in range(0, len(titles), batch_size):
        batch_titles = titles[i:i+batch_size]
        for title in batch_titles:
            body = f'search "{title}"; fields name, involved_companies.company.name, involved_companies.publisher; limit 1;'
            response = requests.post(url, headers=headers, data=body)

            if response.status_code == 200:
                data = response.json()
                if data:
                    publisher = 'Publisher not found'
                    if 'involved_companies' in data[0] and data[0]['involved_companies']:
                        for company in data[0]['involved_companies']:
                            if company.get('publisher', False):
                                publisher = company['company']['name']
                                break
                    game_info = {
                        'Game-title': data[0]['name'],
                        'Publisher': publisher
                    }
                    game_info_list.append(game_info)
                    print(game_info)
                else:
                    game_info_list.append({'Game-title': title, 'Publisher': 'Publisher not found'})
            else:
                print(f'API request failed with status code {response.status_code}')
                game_info_list.append({'Game-title': title, 'Publisher': 'API Error'})
            #time.sleep(1)  # Sleep to respect API rate limit

    return pd.DataFrame(game_info_list)

# %%
#print(search_games(['Smite']))
genres_info = search_games(game_titles)
print(genres_info)
# Out:
# {'Game-title': 'Alien Swarm', 'Publisher': 'Valve'}
# {'Game-title': 'Cities: Skylines - Green Cities', 'Publisher': 'Paradox Interactive'}
# {'Game-title': 'Deus Ex: Human Revolution', 'Publisher': 'Square Enix'}
# {'Game-title': 'Portal 2: In Motion', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Age of Empires II: HD Edition', 'Publisher': 'Microsoft Studios'}
# {'Game-title': 'Call of Duty: Black Ops III', 'Publisher': 'Activision'}
# {'Game-title': 'Call of Duty: Modern Warfare 2', 'Publisher': 'Activision'}
# {'Game-title': 'Call of Duty: Modern Warfare III', 'Publisher': 'Activision'}
# {'Game-title': 'Call of Duty: World at War', 'Publisher': 'Activision'}
# {'Game-title': 'Counter-Strike', 'Publisher': 'Microsoft Game Studios'}
# {'Game-title': 'Counter-Strike: Source', 'Publisher': 'Valve'}
# {'Game-title': 'Rise of Nations: Extended Edition', 'Publisher': 'Microsoft Studios'}
# {'Game-title': 'Thief: Deadly Shadows', 'Publisher': 'Eidos Interactive'}
# {'Game-title': 'Total War: Attila - Celts Culture Pack', 'Publisher': 'Sega Games'}
# {'Game-title': 'Audiosurf 2', 'Publisher': 'Dylan Fitterer'}
# {'Game-title': 'Far Cry 3', 'Publisher': 'Ubisoft Entertainment'}
# {'Game-title': 'Killer Is Dead', 'Publisher': 'XSEED Games'}
# {'Game-title': 'Left 4 Dead 2', 'Publisher': 'Valve'}
# {'Game-title': 'The Elder Scrolls V: Skyrim', 'Publisher': 'Bethesda Softworks'}
# {'Game-title': 'Torchlight II', 'Publisher': 'Runic Games'}
# {'Game-title': 'XCOM: Enemy Unknown', 'Publisher': '2K Games'}
# {'Game-title': 'Counter-Strike: Condition Zero', 'Publisher': 'Sierra Entertainment'}
# {'Game-title': 'Half-Life 2: Episode One', 'Publisher': 'EA Games'}
# {'Game-title': 'Half-Life 2: Episode Two', 'Publisher': 'Valve'}
# {'Game-title': 'Worms Reloaded', 'Publisher': 'Team17'}
# {'Game-title': '7 Days to Die', 'Publisher': 'The Fun Pimps Entertainment LLC'}
# {'Game-title': 'Ark: Survival Evolved', 'Publisher': 'Studio Wildcard'}
# {'Game-title': 'Amnesia: The Dark Descent', 'Publisher': 'Frictional Games'}
# {'Game-title': 'Armikrog', 'Publisher': 'Versus Evil'}
# {'Game-title': 'Batman: Arkham Origins', 'Publisher': 'Warner Bros. Interactive Entertainment'}
# {'Game-title': 'BioShock Infinite', 'Publisher': '2K Games'}
# {'Game-title': 'Borderlands', 'Publisher': '2K Games'}
# {'Game-title': 'Broken Age', 'Publisher': 'Nordic Games Publishing'}
# {'Game-title': 'Brothers: A Tale of Two Sons', 'Publisher': '505 Games'}
# {'Game-title': "Bulletstorm: Duke Nukem's Bulletstorm Tour", 'Publisher': 'Publisher not found'}
# {'Game-title': 'Castle Crashers', 'Publisher': 'The Behemoth'}
# {'Game-title': 'Chivalry: Medieval Warfare', 'Publisher': 'Torn Banner Studios'}
# {'Game-title': 'Dark Souls II', 'Publisher': 'FromSoftware'}
# {'Game-title': 'Dark Souls II: Scholar of the First Sin', 'Publisher': 'Bandai Namco Entertainment'}
# {'Game-title': 'Darksiders II', 'Publisher': 'THQ'}
# {'Game-title': 'Divinity: Original Sin II - Divine Edition', 'Publisher': 'Publisher not found'}
# {'Game-title': 'DmC: Devil May Cry', 'Publisher': 'Capcom'}
# {'Game-title': "Don't Starve", 'Publisher': 'Klei Entertainment'}
# {'Game-title': 'Dungeons of Dredmor', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Dying Light', 'Publisher': 'WB Games'}
# {'Game-title': 'Endless Legend: Monstrous Tales', 'Publisher': 'Publisher not found'}
# {'Game-title': 'FTL: Faster Than Light', 'Publisher': 'Subset Games'}
# {'Game-title': 'Fallout 4', 'Publisher': 'Bethesda Softworks'}
# {'Game-title': 'Fallout: New Vegas', 'Publisher': 'Bandai Namco Entertainment'}
# {'Game-title': 'Galactic Civilizations II: Ultimate Edition', 'Publisher': 'Publisher not found'}
# {'Game-title': "Garry's Mod", 'Publisher': 'Valve'}
# {'Game-title': 'Gone Home', 'Publisher': 'Midnight City'}
# {'Game-title': 'Hitman: Absolution', 'Publisher': 'Square Enix'}
# {'Game-title': 'Hotline Miami', 'Publisher': 'Devolver Digital'}
# {'Game-title': 'Killing Floor 2', 'Publisher': 'Tripwire Interactive'}
# {'Game-title': 'LEGO Batman 2: DC Super Heroes', 'Publisher': 'Feral Interactive'}
# {'Game-title': 'LEGO Marvel Super Heroes', 'Publisher': 'WB Games'}
# {'Game-title': 'Legend of Grimrock', 'Publisher': 'Almost Human Ltd.'}
# {'Game-title': 'Little Inferno', 'Publisher': 'Experimental Gameplay Group'}
# {'Game-title': 'Metal Gear Solid V: Ground Zeroes', 'Publisher': 'Konami'}
# {'Game-title': 'Metal Gear Solid V: The Phantom Pain', 'Publisher': 'Konami'}
# {'Game-title': 'Machinarium', 'Publisher': 'Amanita Design'}
# {'Game-title': 'Mark of the Ninja', 'Publisher': 'Microsoft Studios'}
# {'Game-title': 'Mass Effect 2: Firewalker Pack', 'Publisher': 'Electronic Arts, Inc.'}
# {'Game-title': 'Max Payne 3', 'Publisher': 'Rockstar Games'}
# {'Game-title': 'Metro 2033', 'Publisher': 'THQ'}
# {'Game-title': 'Metro: Last Light', 'Publisher': 'Deep Silver'}
# {'Game-title': 'Mortal Kombat X', 'Publisher': 'WB Games'}
# {'Game-title': 'Natural Selection 2', 'Publisher': 'Unknown Worlds Entertainment'}
# {'Game-title': 'Orcs Must Die! 2', 'Publisher': 'Robot Entertainment'}
# {'Game-title': 'Payday 2', 'Publisher': '505 Games'}
# {'Game-title': 'Pillars of Eternity', 'Publisher': 'Obsidian Entertainment'}
# {'Game-title': 'Prison Architect', 'Publisher': 'Paradox Interactive'}
# {'Game-title': 'Rage', 'Publisher': 'Aspyr Media'}
# {'Game-title': 'Rocket League', 'Publisher': 'Psyonix'}
# {'Game-title': 'Rogue Legacy', 'Publisher': 'Cellar Door Games'}
# {'Game-title': 'Rust', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Star Wars: Knights of the Old Republic II - The Sith Lords', 'Publisher': 'LucasArts'}
# {'Game-title': 'Saints Row: The Third', 'Publisher': 'Square Enix'}
# {'Game-title': 'Sanctum', 'Publisher': 'ARVI VR'}
# {'Game-title': 'Serious Sam 3: BFE', 'Publisher': 'Devolver Digital'}
# {'Game-title': "Shadowrun: Dragonfall - Director's Cut", 'Publisher': 'Harebrained Schemes'}
# {'Game-title': 'Shadowrun Returns', 'Publisher': 'Harebrained Schemes'}
# {'Game-title': "Sid Meier's Civilization: Beyond Earth", 'Publisher': '2K Games'}
# {'Game-title': "Sid Meier's Civilization V", 'Publisher': '2K Games'}
# {'Game-title': 'Sonic Generations', 'Publisher': 'Sega'}
# {'Game-title': 'Starbound', 'Publisher': 'Chucklefish Games'}
# {'Game-title': 'State of Decay', 'Publisher': 'Microsoft Studios'}
# {'Game-title': 'Team Fortress 2: War! Update', 'Publisher': 'Valve'}
# {'Game-title': 'Terraria', 'Publisher': 'Headup Games'}
# {'Game-title': 'Block Slime Cave', 'Publisher': 'Gotcha Gotcha Games'}
# {'Game-title': 'Märchen Forest: Mylne and the Forest Gift', 'Publisher': 'Primary Orbit'}
# {'Game-title': 'The Long Dark', 'Publisher': 'Hinterland Studio Inc.'}
# {'Game-title': 'The Walking Dead', 'Publisher': 'Telltale Games'}
# {'Game-title': 'The Witcher 3: Wild Hunt + Dark Souls III', 'Publisher': 'Bandai Namco Entertainment'}
# {'Game-title': 'The Wolf Among Us: Episode 5 - Cry Wolf', 'Publisher': 'Telltale Games'}
# {'Game-title': 'Thief: Deadly Shadows', 'Publisher': 'Eidos Interactive'}
# {'Game-title': "Tom Clancy's Splinter Cell: Blacklist", 'Publisher': 'Ubisoft Entertainment'}
# {'Game-title': 'Tomb Raider: The Angel of Darkness', 'Publisher': 'Eidos Interactive'}
# {'Game-title': 'Torchlight II', 'Publisher': 'Runic Games'}
# {'Game-title': 'Transformers: Fall of Cybertron', 'Publisher': 'Activision'}
# {'Game-title': 'Tropico 4', 'Publisher': 'FX Interactive'}
# {'Game-title': 'Unturned', 'Publisher': 'Smartly Dressed Games'}
# {'Game-title': 'Warhammer: End Times - Vermintide', 'Publisher': 'Fatshark'}
# {'Game-title': 'Wasteland 2', 'Publisher': 'inXile Entertainment'}
# {'Game-title': 'Half-Life 2: MMod - Half-Life 2: Update', 'Publisher': 'Gunship_Mark_II'}
# {'Game-title': 'Alan Wake II', 'Publisher': 'Epic Games'}
# {'Game-title': "Alan Wake's American Nightmare", 'Publisher': 'Nordic Games Publishing'}
# {'Game-title': 'Brink of Consciousness: Dorian Gray Syndrome', 'Publisher': 'Plug In Digital'}
# {'Game-title': 'Battlefield: Bad Company 2', 'Publisher': 'Electronic Arts'}
# {'Game-title': 'Call of Duty: Advanced Warfare', 'Publisher': 'Activision'}
# {'Game-title': 'Call of Duty: Black Ops II', 'Publisher': 'Activision'}
# {'Game-title': 'Call of Duty: Ghosts', 'Publisher': 'Activision'}
# {'Game-title': 'Day of Defeat: Source', 'Publisher': 'Valve'}
# {'Game-title': 'DayZ', 'Publisher': 'Bohemia Interactive Studio'}
# {'Game-title': 'Duke Nukem Forever', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Eufloria', 'Publisher': 'Omni Systems'}
# {'Game-title': 'F.E.A.R. 3', 'Publisher': 'WB Games'}
# {'Game-title': 'Front Mission Evolved', 'Publisher': 'Square Enix'}
# {'Game-title': 'Half-Life: Source', 'Publisher': 'Valve'}
# {'Game-title': 'I am alive', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Killing Floor', 'Publisher': 'Tripwire Interactive'}
# {'Game-title': 'Mass Effect', 'Publisher': 'Electronic Arts'}
# {'Game-title': 'Operation Flashpoint: Red River', 'Publisher': 'Codemasters'}
# {'Game-title': 'Osmos+', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Warcraft II: Beyond the Dark Portal', 'Publisher': 'Blizzard Entertainment'}
# {'Game-title': 'Red Faction: Guerrilla - Steam Edition', 'Publisher': 'THQ Nordic'}
# {'Game-title': 'Serious Sam HD: The First Encounter', 'Publisher': 'Devolver Digital'}
# {'Game-title': 'Sniper Elite V2', 'Publisher': 'Rebellion Developments'}
# {'Game-title': 'Spec Ops: The Line', 'Publisher': '2K Games'}
# {'Game-title': 'Synergy', 'Publisher': 'Goblinz Publishing'}
# {'Game-title': 'Wolfenstein 3D', 'Publisher': 'id Software'}
# {'Game-title': 'F1 2014', 'Publisher': 'Codemasters'}
# {'Game-title': 'ArmA 2: Operation Arrowhead', 'Publisher': 'Meridian4'}
# {'Game-title': 'Brothers in Arms: Road to Hill 30', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Company of Heroes: Tales of Valor', 'Publisher': 'THQ'}
# {'Game-title': 'Might & Magic: Heroes VI', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Ares', 'Publisher': 'TimeTop'}
# {'Game-title': 'Age of Chivalry', 'Publisher': 'Steam'}
# {'Game-title': "Assassin's Creed II", 'Publisher': 'Ubisoft Entertainment'}
# {'Game-title': "Assassin's Creed III", 'Publisher': 'Ubisoft Entertainment'}
# {'Game-title': "Assassin's Creed Revelations", 'Publisher': 'Ubisoft Entertainment'}
# {'Game-title': 'Awesomenauts', 'Publisher': 'Ronimo Games'}
# {'Game-title': 'Bit.Trip Runner', 'Publisher': 'Aksys Games'}
# {'Game-title': 'Blocks That Matter', 'Publisher': 'Swing Swing Submarine'}
# {'Game-title': 'Braid', 'Publisher': 'Number None Inc.'}
# {'Game-title': "Brothers in Arms: Hell's Highway", 'Publisher': 'Publisher not found'}
# {'Game-title': 'Burnout Paradise: The Ultimate Box', 'Publisher': 'Electronic Arts'}
# {'Game-title': 'Crysis 2: Maximum Edition', 'Publisher': 'Electronic Arts'}
# {'Game-title': 'Crysis Warhead', 'Publisher': 'Electronic Arts'}
# {'Game-title': 'DeathSpank', 'Publisher': 'Electronic Arts'}
# {'Game-title': 'Defense Grid: The Awakening', 'Publisher': 'Microsoft'}
# {'Game-title': 'Deus Ex: Human Revolution - The Missing Link', 'Publisher': 'Square Enix'}
# {'Game-title': 'Dota 2', 'Publisher': 'Valve'}
# {'Game-title': 'Empire: Total War', 'Publisher': 'Sega'}
# {'Game-title': 'Europa Universalis III', 'Publisher': 'Paradox Interactive'}
# {'Game-title': 'Faerie Solitaire', 'Publisher': 'Subsoap'}
# {'Game-title': 'Frozen Synapse', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Galcon Fusion', 'Publisher': 'Hassey Enterprises, Inc'}
# {'Game-title': 'Gratuitous Space Battles', 'Publisher': 'Positech Games'}
# {'Game-title': 'Half-Life 2: Deathmatch', 'Publisher': 'Valve'}
# {'Game-title': 'Half-Life: Blue Shift', 'Publisher': 'supadupaplex'}
# {'Game-title': 'Just Cause 2', 'Publisher': 'Eidos Interactive'}
# {'Game-title': "King's Bounty: Armored Princess", 'Publisher': 'Focus Multimedia'}
# {'Game-title': "King's Bounty: Crossworlds", 'Publisher': 'Fulqrum Publishing'}
# {'Game-title': 'McPixel 3: McPixel Visits Grandma', 'Publisher': 'Devolver Digital'}
# {'Game-title': 'Mount & Blade: Warband', 'Publisher': 'Paradox Interactive'}
# {'Game-title': 'Napoleon: Total War', 'Publisher': 'Sega'}
# {'Game-title': 'Orcs Must Die!', 'Publisher': 'Microsoft Game Studios'}
# {'Game-title': 'Payday: The Heist', 'Publisher': 'Sony Online Entertainment'}
# {'Game-title': 'Plain Sight', 'Publisher': 'Beatnik Games'}
# {'Game-title': 'Psychonauts', 'Publisher': 'THQ'}
# {'Game-title': 'Renegade Ops', 'Publisher': 'Sega'}
# {'Game-title': 'Titan Revenge', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Rising Storm/Red Orchestra 2 Multiplayer', 'Publisher': 'Tripwire Interactive'}
# {'Game-title': 'Rock of Ages', 'Publisher': 'Atlus'}
# {'Game-title': 'S.T.A.L.K.E.R.: Shadow of Chernobyl', 'Publisher': 'THQ'}
# {'Game-title': 'Serious Sam HD: The Second Encounter', 'Publisher': 'Devolver Digital'}
# {'Game-title': 'SpaceChem', 'Publisher': 'Zachtronics Industries'}
# {'Game-title': 'Stacks on Stacks (On Stacks)', 'Publisher': 'Herringbone Games'}
# {'Game-title': 'Steamworld Dig 2 + Steamworld Dig', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Super Meat Boy Handheld!', 'Publisher': 'Team Meat'}
# {'Game-title': "Tales of Maj'Eyal", 'Publisher': 'Netcore Games'}
# {'Game-title': 'Dragon Ball Z: Super Butouden 3', 'Publisher': 'Bandai'}
# {'Game-title': 'The Binding of Isaac', 'Publisher': 'Edmund McMillen'}
# {'Game-title': 'The Matrix: Path of Neo', 'Publisher': 'Atari, Inc.'}
# {'Game-title': 'The Secret of Monkey Island: Special Edition', 'Publisher': 'LucasArts'}
# {'Game-title': 'The Stanley Parable', 'Publisher': 'Galactic Cafe'}
# {'Game-title': 'The Typing of the Dead: Overkill', 'Publisher': 'Sega'}
# {'Game-title': 'Titan Quest: Immortal Throne', 'Publisher': 'THQ'}
# {'Game-title': 'Total War: Shogun 2 - Saints and Heroes Unit Pack', 'Publisher': 'Sega'}
# {'Game-title': 'VVVVVV', 'Publisher': 'Nicalis, Inc.'}
# {'Game-title': 'Vampire: The Masquerade - Bloodlines', 'Publisher': 'Activision'}
# {'Game-title': 'Zeno Clash II', 'Publisher': 'Atlus'}
# {'Game-title': 'Day of Defeat', 'Publisher': 'Activision'}
# {'Game-title': 'Half-Life 2: MMod - Half-Life 2: Update', 'Publisher': 'Gunship_Mark_II'}
# {'Game-title': 'Half-Life: Opposing Force', 'Publisher': 'Sierra Entertainment'}
# {'Game-title': "Sid Meier's Civilization III: Complete", 'Publisher': '2K Games'}
# {'Game-title': 'Sniper Elite', 'Publisher': 'MC2 France'}
# {'Game-title': 'War Inc. Battlezone', 'Publisher': 'Online Warmongers Group Inc.'}
# {'Game-title': 'Grand Theft Auto IV', 'Publisher': 'Rockstar Games'}
# {'Game-title': 'Kingdom Rush', 'Publisher': 'Armor Games'}
# {'Game-title': 'L.A. Noire', 'Publisher': 'Rockstar Games'}
# {'Game-title': 'Sleeping Dogs', 'Publisher': 'Bandai Namco Entertainment'}
# {'Game-title': 'Sometimes Always Monsters', 'Publisher': 'Vagabond Dog'}
# {'Game-title': 'Blood Bowl: Legendary Edition', 'Publisher': 'Focus Entertainment'}
# {'Game-title': 'Botanicula', 'Publisher': 'Amanita Design'}
# {'Game-title': 'Broforce', 'Publisher': 'Devolver Digital'}
# {'Game-title': 'Car Mechanic Simulator 2014', 'Publisher': 'PlayWay S.A.'}
# {'Game-title': 'CastleStorm', 'Publisher': 'Microsoft Studios'}
# {'Game-title': 'Cossacks II: Napoleonic Wars', 'Publisher': 'cdv Software Entertainment'}
# {'Game-title': 'Elven Legacy', 'Publisher': 'Paradox Interactive'}
# {'Game-title': 'FlatOut 2', 'Publisher': 'Konami'}
# {'Game-title': 'Game Dev Tycoon', 'Publisher': 'Greenheart Games'}
# {'Game-title': 'Giana Sisters: Twisted Dreams', 'Publisher': 'Black Forest Games'}
# {'Game-title': 'Guacamelee!: Gold Edition', 'Publisher': 'Drinkbox Studios'}
# {'Game-title': 'Kerbal Space Program', 'Publisher': 'Private Division'}
# {'Game-title': 'King of Dragon Pass', 'Publisher': 'A Sharp, LLC'}
# {'Game-title': 'LEGO Worlds', 'Publisher': 'WB Games'}
# {'Game-title': 'Magic 2014: Duels of the Planeswalkers', 'Publisher': 'Wizards of the Coast LLC'}
# {'Game-title': 'Magic: The Gathering - Duels of the Planeswalkers 2015', 'Publisher': 'Microsoft Studios'}
# {'Game-title': 'Magic Duels', 'Publisher': 'Wizards of the Coast LLC'}
# {'Game-title': 'Majesty 2: Kingmaker', 'Publisher': 'Paradox Interactive'}
# {'Game-title': 'Men of War II', 'Publisher': 'Fulqrum Publishing'}
# {'Game-title': 'Octodad: Dadliest Catch', 'Publisher': 'Young Horses'}
# {'Game-title': 'Pat & Mat', 'Publisher': 'Centauri Production'}
# {'Game-title': 'Rayman Legends', 'Publisher': 'Ubisoft Entertainment'}
# {'Game-title': 'Red Orchestra: Ostfront 41-45', 'Publisher': 'Tripwire Interactive'}
# {'Game-title': 'Scribblenauts Unlimited', 'Publisher': 'WB Games'}
# {'Game-title': "Sid Meier's Ace Patrol", 'Publisher': '2K Games'}
# {'Game-title': "Sid Meier's Civilization IV: Colonization", 'Publisher': '2K Games'}
# {'Game-title': "Sid Meier's Pirates!", 'Publisher': '2K Games'}
# {'Game-title': "Sid Meier's Railroads!", 'Publisher': '2K Games'}
# {'Game-title': 'Skulls of the Shogun', 'Publisher': '17-BIT'}
# {'Game-title': 'Space Hulk: Space Wolves Chapter', 'Publisher': 'Full Control'}
# {'Game-title': 'Spintires', 'Publisher': 'Oovee Game Studios'}
# {'Game-title': 'Supreme Commander', 'Publisher': 'THQ'}
# {'Game-title': 'The Banner Saga 3', 'Publisher': 'Versus Evil'}
# {'Game-title': 'This War of Mine: War Child Charity', 'Publisher': '11 bit studios'}
# {'Game-title': 'Ticket to Ride: India', 'Publisher': 'Days of Wonder'}
# {'Game-title': 'TowerFall Ascension', 'Publisher': 'Extremely OK Games'}
# {'Game-title': 'Trine 2', 'Publisher': 'Atlus'}
# {'Game-title': 'Ultimate General: Gettysburg', 'Publisher': 'Game-Labs'}
# {'Game-title': 'Warhammer 40,000: Dawn of War II', 'Publisher': 'THQ'}
# {'Game-title': 'Warhammer 40,000: Space Marine', 'Publisher': 'THQ'}
# {'Game-title': 'World of Goo', 'Publisher': '2D Boy'}
# {'Game-title': 'Arma 3', 'Publisher': 'Bohemia Interactive Studio'}
# {'Game-title': 'Company of Heroes 2', 'Publisher': 'Sega'}
# {'Game-title': 'Dungeon Defenders II', 'Publisher': 'Trendy Entertainment'}
# {'Game-title': 'Dungeon Defenders II', 'Publisher': 'Trendy Entertainment'}
# {'Game-title': 'Final Fantasy VII & Final Fantasy VIII Remastered Twin Pack', 'Publisher': 'Square Enix'}
# {'Game-title': 'Planetary Annihilation', 'Publisher': 'Planetary Annihilation Inc'}
# {'Game-title': 'Planetary Annihilation: Titans', 'Publisher': 'Planetary Annihilation Inc'}
# {'Game-title': 'Sins of a Solar Empire: Trinity', 'Publisher': 'Stardock'}
# {'Game-title': 'Street Fighter IV', 'Publisher': 'Capcom'}
# {'Game-title': 'Supreme Commander 2', 'Publisher': 'Square Enix'}
# {'Game-title': 'Unreal Tournament III: Black Edition', 'Publisher': 'Epic Games'}
# {'Game-title': 'World in Conflict: Soviet Assault', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Clicker Heroes', 'Publisher': 'Playsaurus'}
# {'Game-title': 'Darkest Dungeon: The Musketeer', 'Publisher': 'Red Hook Studios'}
# {'Game-title': 'Endless Dungeon', 'Publisher': 'Sega'}
# {'Game-title': 'Hero Academy', 'Publisher': 'Robot Entertainment'}
# {'Game-title': 'Path of Exile', 'Publisher': 'Grinding Gear Games'}
# {'Game-title': 'Retro-Pixel Castles', 'Publisher': 'Raymond Doerr'}
# {'Game-title': 'Rocksmith 2014', 'Publisher': 'Ubisoft Entertainment'}
# {'Game-title': 'Tap Tap Infinity', 'Publisher': 'Publisher not found'}
# {'Game-title': 'War of the Roses', 'Publisher': 'Paradox Interactive'}
# {'Game-title': 'DC Universe Online', 'Publisher': 'WB Games'}
# {'Game-title': 'Doom II: Hell on Earth', 'Publisher': 'id Software'}
# {'Game-title': 'Bejeweled 2 Deluxe', 'Publisher': 'PopCap Games'}
# {'Game-title': 'BioShock 2', 'Publisher': '2K Games'}
# {'Game-title': 'Cave Story+', 'Publisher': 'Nicalis, Inc.'}
# {'Game-title': 'Duke Nukem 3D: Megaton Edition', 'Publisher': 'Devolver Digital'}
# {'Game-title': 'Grid 2', 'Publisher': 'Codemasters'}
# {'Game-title': 'Limbo', 'Publisher': 'Microsoft Game Studios'}
# {'Game-title': 'Poker Night 2', 'Publisher': 'Telltale Games'}
# {'Game-title': 'Quake: Coffee Quake', 'Publisher': 'Publisher not found'}
# {'Game-title': "Sid Meier's Civilization IV: Colonization", 'Publisher': '2K Games'}
# {'Game-title': "Sid Meier's Civilization IV: Warlords", 'Publisher': 'Take-Two Interactive'}
# {'Game-title': 'South Park: The Stick of Truth', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Wolfenstein: The New Order', 'Publisher': 'Bethesda Softworks'}
# {'Game-title': 'Wolfenstein: The Old Blood', 'Publisher': 'Bethesda Softworks'}
# {'Game-title': 'F1 2011', 'Publisher': 'Codemasters'}
# {'Game-title': 'Trials Evolution: Gold Edition', 'Publisher': 'Ubisoft Entertainment'}
# {'Game-title': 'Age of Wonders III', 'Publisher': 'Triumph Studios'}
# {'Game-title': 'Black Mesa', 'Publisher': 'Crowbar Collective'}
# {'Game-title': 'Blacklight: Retribution', 'Publisher': 'Perfect World Entertainment'}
# {'Game-title': 'Bloodline Champions', 'Publisher': 'Funcom'}
# {'Game-title': 'Call of Duty: Black Ops II - Nuketown Zombies', 'Publisher': 'Activision'}
# {'Game-title': 'Dirty Bomb', 'Publisher': 'Nexon Co. Ltd.'}
# {'Game-title': 'H1Z1', 'Publisher': 'Sony Online Entertainment'}
# {'Game-title': 'Loadout', 'Publisher': 'Edge of Reality'}
# {'Game-title': 'PlanetSide 2', 'Publisher': 'Daybreak Game Company'}
# {'Game-title': 'Reign of Kings', 'Publisher': 'CodeJunkies'}
# {'Game-title': 'Sanctum 2', 'Publisher': 'D3 Publisher'}
# {'Game-title': 'SpeedRunners', 'Publisher': 'tinyBuild'}
# {'Game-title': 'Tera', 'Publisher': 'En Masse Entertainment'}
# {'Game-title': 'Warframe', 'Publisher': 'Digital Extremes'}
# {'Game-title': 'ArcheAge', 'Publisher': 'Tencent Games'}
# {'Game-title': 'Arma 2', 'Publisher': '505 Games'}
# {'Game-title': 'Robocraft', 'Publisher': 'Freejam Games'}
# {'Game-title': 'Section 8: Prejudice', 'Publisher': 'Atari, Inc.'}
# {'Game-title': 'X-COM: Terror From the Deep', 'Publisher': 'Hasbro Interactive'}
# {'Game-title': 'Far Cry 2', 'Publisher': 'Publisher not found'}
# {'Game-title': 'RaceRoom Racing Experience', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Ski Region Simulator', 'Publisher': 'Giants Software'}
# {'Game-title': 'Papers, Please', 'Publisher': '3909'}
# {'Game-title': 'Wargame: AirLand Battle', 'Publisher': 'Focus Entertainment'}
# {'Game-title': 'Wargame: European Escalation', 'Publisher': 'Focus Entertainment'}
# {'Game-title': 'Total War: Rome II - Emperor Edition', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Hawken', 'Publisher': 'Meteor Entertainment'}
# {'Game-title': 'IL-2 Sturmovik: 1946', 'Publisher': '1C-777'}
# {'Game-title': 'IL-2 Sturmovik: Battle of Stalingrad', 'Publisher': '1C Game Studios'}
# {'Game-title': 'IL-2 Sturmovik: Cliffs of Dover', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Insurgency', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Total War: Medieval II', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Craft the World', 'Publisher': 'Black Maple Games'}
# {'Game-title': 'Dwarf Fortress', 'Publisher': 'Bay 12 Games'}
# {'Game-title': 'Farm for your Life', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Godus', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Infinifactory', 'Publisher': 'Zachtronics'}
# {'Game-title': 'Mad Games Tycoon', 'Publisher': 'Toplitz Productions'}
# {'Game-title': 'Planetbase', 'Publisher': 'Madruga Works'}
# {'Game-title': 'Poly Bridge', 'Publisher': 'Dry Cactus'}
# {'Game-title': 'Port Royale 3: Pirates & Merchants', 'Publisher': 'Kalypso Media'}
# {'Game-title': 'Rescue 2', 'Publisher': 'rondomedia Marketing & Vertriebs GmbH'}
# {'Game-title': 'RPG Maker VX Ace', 'Publisher': 'Enterbrain'}
# {'Game-title': 'Railroad Pioneer', 'Publisher': 'Publisher not found'}
# {'Game-title': 'The Escapists + The Escapists 2', 'Publisher': 'Team17'}
# {'Game-title': 'Tropico 5: Gone Green', 'Publisher': 'Kalypso Media Digital'}
# {'Game-title': 'Windward', 'Publisher': 'Tasharen Entertainment Inc.'}
# {'Game-title': 'Assetto Corsa Competizione: Intercontinental GT Pack', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Colin McRae: Dirt 2', 'Publisher': 'Codemasters'}
# {'Game-title': 'Euro Truck Simulator 2: Legendary Edition', 'Publisher': 'SCS Software'}
# {'Game-title': 'F1 2010', 'Publisher': 'Codemasters'}
# {'Game-title': 'SimCity 4: Deluxe Edition', 'Publisher': 'Electronic Arts'}
# {'Game-title': 'Warhammer 40,000: Dawn of War II - Chaos Rising', 'Publisher': 'THQ'}
# {'Game-title': 'Enemy Territory: Quake Wars', 'Publisher': 'Activision'}
# {'Game-title': 'Bully: Scholarship Edition', 'Publisher': 'Rockstar Games'}
# {'Game-title': 'Grim Fandango Remastered', 'Publisher': 'Double Fine Productions'}
# {'Game-title': "America's Army: Proving Grounds", 'Publisher': 'U.S. Army'}
# {'Game-title': 'Dead Island: Epidemic', 'Publisher': 'Deep Silver'}
# {'Game-title': 'Marvel Heroes', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Sins of a Dark Age', 'Publisher': 'Ironclad Games'}
# {'Game-title': 'The Lord of the Rings Online', 'Publisher': 'Codemasters'}
# {'Game-title': 'The Darkside Detective: A Fumble in the Dark - Tales of the Darkside', 'Publisher': 'Akupara Games'}
# {'Game-title': 'Crypt of the NecroDancer: Synchrony', 'Publisher': 'Brace Yourself Games'}
# {'Game-title': 'Grim Dawn', 'Publisher': 'Crate Entertainment'}
# {'Game-title': 'MapleStory', 'Publisher': 'Nexon Co. Ltd.'}
# {'Game-title': 'Star Conflict', 'Publisher': 'Gaijin Entertainment'}
# {'Game-title': 'Stronghold 3', 'Publisher': 'SouthPeak Interactive'}
# {'Game-title': 'Besiege', 'Publisher': 'Spiderling Games'}
# {'Game-title': 'Dirt 3', 'Publisher': 'Codemasters'}
# {'Game-title': 'Divine Souls', 'Publisher': 'Publisher not found'}
# {'Game-title': "Final Fantasy XIV: A Realm Reborn - Collector's Edition", 'Publisher': 'Square Enix'}
# {'Game-title': 'GunZ 2: The Second Duel', 'Publisher': 'Masangsoft, Inc.'}
# {'Game-title': 'Lost Planet 3', 'Publisher': 'Capcom'}
# {'Game-title': 'Rift', 'Publisher': 'Trion Worlds'}
# {'Game-title': 'Remember, Remember', 'Publisher': 'Publisher not found'}
# {'Game-title': 'SolForge', 'Publisher': 'Stone Blade Entertainment'}
# {'Game-title': 'The Bureau: XCOM Declassified', 'Publisher': '2K Games'}
# {'Game-title': 'Age of Empires III: Complete Collection', 'Publisher': 'Microsoft Studios'}
# {'Game-title': 'Cities XL 2012', 'Publisher': 'Focus Entertainment'}
# {'Game-title': 'Eve Online', 'Publisher': 'CCP Games'}
# {'Game-title': 'Elite: Dangerous', 'Publisher': 'Frontier Developments'}
# {'Game-title': 'Just Cause 3', 'Publisher': 'Square Enix'}
# {'Game-title': 'Saints Row IV', 'Publisher': 'Deep Silver'}
# {'Game-title': "Strike Suit Zero: Director's Cut", 'Publisher': 'Born Ready Games'}
# {'Game-title': 'Unreal Tournament: Game of the Year Edition', 'Publisher': 'Epic Games'}
# {'Game-title': 'Defiance', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Fallout 3: Game of the Year Edition', 'Publisher': 'Bethesda Softworks'}
# {'Game-title': 'Grand Theft Auto: Vice City', 'Publisher': 'Rockstar Games'}
# {'Game-title': 'The Incredible Adventures of Van Helsing', 'Publisher': 'NeoCore Games'}
# {'Game-title': 'Dirt Showdown', 'Publisher': 'Codemasters'}
# {'Game-title': 'Angry Video Game Nerd Adventures', 'Publisher': 'ScrewAttack Games'}
# {'Game-title': 'Anomaly 2', 'Publisher': '11 bit studios'}
# {'Game-title': 'Ascendant', 'Publisher': 'Imagisphere'}
# {'Game-title': 'BattleBlock Theater', 'Publisher': 'Microsoft Studios'}
# {'Game-title': 'Ben There, Dan That!', 'Publisher': 'Size Five Games'}
# {'Game-title': 'Choice Chamber', 'Publisher': 'Studio Bean'}
# {'Game-title': 'Cook, Serve, Delicious!', 'Publisher': 'Vertigo Gaming'}
# {'Game-title': "Defender's Quest: Valley of the Forgotten", 'Publisher': 'Publisher not found'}
# {'Game-title': 'Desktop Dungeons', 'Publisher': 'QCF Design'}
# {'Game-title': 'Gauntlet', 'Publisher': 'Tiger Electronics'}
# {'Game-title': 'Global Agenda', 'Publisher': 'Hi-Rez Studios'}
# {'Game-title': 'Guild of Dungeoneering', 'Publisher': 'Versus Evil'}
# {'Game-title': 'Hacknet', 'Publisher': 'Fellow Traveller'}
# {'Game-title': 'Hammerwatch II', 'Publisher': 'Modus Games'}
# {'Game-title': 'Hand of Fate 2', 'Publisher': 'Unbroken Studios'}
# {'Game-title': 'Siege Hero', 'Publisher': 'Armor Games Studios'}
# {'Game-title': 'Legend of Dungeon: Masters', 'Publisher': 'Robot Loves Kitty'}
# {'Game-title': 'Middle-earth: Shadow of Mordor', 'Publisher': 'WB Games'}
# {'Game-title': 'Monday Night Combat', 'Publisher': 'Uber Entertainment'}
# {'Game-title': 'Need for Speed: Undercover', 'Publisher': 'EA Mobile'}
# {'Game-title': 'Never Alone: Kisima Ingitchuna', 'Publisher': 'E-Line Media'}
# {'Game-title': 'Nimble Quest', 'Publisher': 'NimbleBit'}
# {'Game-title': 'Nosgoth', 'Publisher': 'Square Enix'}
# {'Game-title': 'Ori and the Blind Forest: Definitive Edition', 'Publisher': 'Microsoft Studios'}
# {'Game-title': 'Our Darker Purpose', 'Publisher': 'Avidly Wild Games'}
# {'Game-title': 'Rampage Knights', 'Publisher': 'Rake in Grass'}
# {'Game-title': 'Risk of Rain 2', 'Publisher': 'Gearbox Publishing'}
# {'Game-title': 'Robot Roller-Derby Disco Dodgeball', 'Publisher': '82 Apps'}
# {'Game-title': 'Sacred Citadel', 'Publisher': 'Deep Silver'}
# {'Game-title': 'Spelunky', 'Publisher': 'Microsoft Studios'}
# {'Game-title': 'The Binding of Isaac: Rebirth', 'Publisher': 'Nicalis, Inc.'}
# {'Game-title': 'The Mighty Quest for Epic Loot', 'Publisher': 'Publisher not found'}
# {'Game-title': 'The Walking Dead: Season Two', 'Publisher': 'Skybound Games'}
# {'Game-title': 'Time Gentlemen, Please!', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Volgarr the Viking', 'Publisher': 'Adult Swim Games'}
# {'Game-title': 'Warhammer 40,000: Dawn of War II - Retribution', 'Publisher': 'THQ'}
# {'Game-title': 'Aliens: Colonial Marines', 'Publisher': 'Sega'}
# {'Game-title': 'Freedom Force', 'Publisher': 'Crave Entertainment'}
# {'Game-title': 'Titan Quest II', 'Publisher': 'THQ Nordic'}
# {'Game-title': "Tom Clancy's Splinter Cell: Double Agent", 'Publisher': 'Publisher not found'}
# {'Game-title': 'The Last Remnant Remastered', 'Publisher': 'Square Enix'}
# {'Game-title': 'Half-Life 2: Lost Coast', 'Publisher': 'Valve'}
# {'Game-title': 'Alpha Protocol', 'Publisher': 'Sega'}
# {'Game-title': 'Anomaly: Warzone Earth', 'Publisher': '11 bit studios'}
# {'Game-title': "Assassin's Creed Bundle: Assassin's Creed Valhalla, Assassin's Creed Odyssey, and Assassin's Creed Origins", 'Publisher': 'Ubisoft Entertainment'}
# {'Game-title': 'Car Mechanic Simulator 2015: Car Stripping', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Cogs', 'Publisher': 'Lazy 8 Studios'}
# {'Game-title': 'Command & Conquer: Red Alert 3', 'Publisher': 'Electronic Arts'}
# {'Game-title': 'Company of Heroes', 'Publisher': 'THQ'}
# {'Game-title': 'Divinity II: The Dragon Knight Saga', 'Publisher': 'Focus Entertainment'}
# {'Game-title': 'Divinity: Original Sin - Enhanced Edition', 'Publisher': 'Focus Entertainment'}
# {'Game-title': 'Dragon Age II', 'Publisher': 'Electronic Arts'}
# {'Game-title': 'Dragon Age: Origins', 'Publisher': 'Electronic Arts'}
# {'Game-title': 'Driver: San Francisco', 'Publisher': 'Ubisoft Entertainment'}
# {'Game-title': 'Earth 2160', 'Publisher': 'Deep Silver'}
# {'Game-title': 'Rescue Team: Evil Genius', 'Publisher': 'Alawar Premium'}
# {'Game-title': 'F1 2012', 'Publisher': 'Codemasters'}
# {'Game-title': 'Final Fantasy XIII', 'Publisher': 'Square Enix'}
# {'Game-title': 'Farming Simulator 15', 'Publisher': 'Focus Entertainment'}
# {'Game-title': 'Farming Simulator 2011', 'Publisher': 'Giants Software'}
# {'Game-title': 'Farming Simulator 2013', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Grid', 'Publisher': 'Codemasters'}
# {'Game-title': 'Grid: Autosport', 'Publisher': 'Codemasters'}
# {'Game-title': 'Ghostbusters: The Video Game', 'Publisher': 'Sony Computer Entertainment'}
# {'Game-title': 'Hitman: Blood Money', 'Publisher': 'Eidos Interactive'}
# {'Game-title': 'Impire', 'Publisher': 'Paradox Interactive'}
# {'Game-title': 'Metal Gear Rising: Revengeance', 'Publisher': 'Konami'}
# {'Game-title': 'Mad Max', 'Publisher': 'WB Games'}
# {'Game-title': 'Mafia II', 'Publisher': '2K Games'}
# {'Game-title': 'Need for Speed: Hot Pursuit - Remastered', 'Publisher': 'Electronic Arts'}
# {'Game-title': 'Of Orcs and Men', 'Publisher': 'Focus Entertainment'}
# {'Game-title': 'Oil Rush', 'Publisher': 'Unigine Holding'}
# {'Game-title': 'Overlord II', 'Publisher': 'Codemasters'}
# {'Game-title': 'Pirates of Black Cove', 'Publisher': 'Paradox Interactive'}
# {'Game-title': 'Prime World: Defenders', 'Publisher': 'Nival'}
# {'Game-title': 'Prototype', 'Publisher': 'Nikita Kryukov'}
# {'Game-title': 'Quantum Conundrum', 'Publisher': 'Square Enix'}
# {'Game-title': 'Race 07', 'Publisher': 'SimBin'}
# {'Game-title': 'Need for Speed: Shift 2 Unleashed', 'Publisher': 'Electronic Arts'}
# {'Game-title': 'SpellForce 2: Gold Edition', 'Publisher': 'THQ Nordic'}
# {'Game-title': 'Star Wars: Jedi Knight II - Jedi Outcast', 'Publisher': 'CyberFront'}
# {'Game-title': 'Stronghold 2', 'Publisher': '2K Games'}
# {'Game-title': 'The Lord of the Rings: War in the North', 'Publisher': 'WB Games'}
# {'Game-title': 'Tomb Raider: Underworld', 'Publisher': 'Eidos Interactive'}
# {'Game-title': 'Railworks 2: Train Simulator', 'Publisher': 'RailSimulator.com Ltd'}
# {'Game-title': 'Trine 2', 'Publisher': 'Atlus'}
# {'Game-title': 'Tropico 3: Steam Special Edition', 'Publisher': 'Kalypso Media Digital'}
# {'Game-title': 'Evolve', 'Publisher': '2K Games'}
# {'Game-title': 'Grey Goo', 'Publisher': 'Grey Box'}
# {'Game-title': 'Space Engineers', 'Publisher': 'Keen Software House'}
# {'Game-title': 'FireFall', 'Publisher': 'Red 5 Studios'}
# {'Game-title': 'Alien: Isolation', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Amnesia: A Machine for Pigs', 'Publisher': 'Frictional Games'}
# {'Game-title': 'BioShock', 'Publisher': 'Starwave'}
# {'Game-title': 'Crusader Kings II', 'Publisher': 'Paradox Interactive'}
# {'Game-title': 'Crysis', 'Publisher': 'Electronic Arts'}
# {'Game-title': 'Darwinia+', 'Publisher': 'Introversion Software'}
# {'Game-title': 'Dead Space', 'Publisher': 'Electronic Arts'}
# {'Game-title': 'Dead Space 2', 'Publisher': 'Electronic Arts'}
# {'Game-title': 'Dragon Age: Origins - Ultimate Edition', 'Publisher': 'Electronic Arts, Inc.'}
# {'Game-title': 'Europa Universalis IV', 'Publisher': 'Paradox Interactive'}
# {'Game-title': 'Fear of Fear', 'Publisher': 'Publisher not found'}
# {'Game-title': 'F.E.A.R. 2: Project Origin', 'Publisher': 'WB Games'}
# {'Game-title': 'Fate of the World', 'Publisher': 'Red Redemption'}
# {'Game-title': 'Franchise Hockey Manager 2014', 'Publisher': 'Out Of The Park Developments'}
# {'Game-title': 'Galactic Civilizations III', 'Publisher': 'Stardock'}
# {'Game-title': 'Game of Thrones: A Telltale Games Series', 'Publisher': 'Telltale Games'}
# {'Game-title': 'Homeworld: Remastered Collection', 'Publisher': 'Gearbox Publishing'}
# {'Game-title': 'Infested Planet', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Medieval II: Total War - Kingdoms', 'Publisher': 'Sega'}
# {'Game-title': 'Orion: Prelude', 'Publisher': 'Dankie'}
# {'Game-title': 'Outlast', 'Publisher': 'Red Barrels'}
# {'Game-title': 'Plague Inc: Evolved', 'Publisher': 'Ndemic Creations'}
# {'Game-title': 'Prey', 'Publisher': 'Bethesda Softworks'}
# {'Game-title': 'R.U.S.E.', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Risk: Factions', 'Publisher': 'Electronic Arts'}
# {'Game-title': "Sid Meier's Civilization IV: Beyond the Sword", 'Publisher': '2K Games'}
# {'Game-title': 'Sins of a Solar Empire: Rebellion', 'Publisher': 'Stardock'}
# {'Game-title': 'Star Wars: Knights of the Old Republic', 'Publisher': 'LucasArts'}
# {'Game-title': 'Supreme Commander: Forged Alliance', 'Publisher': 'THQ'}
# {'Game-title': 'The Elder Scrolls IV: Oblivion', 'Publisher': '2K Games'}
# {'Game-title': 'Wings of Prey: Wings of Luftwaffe', 'Publisher': 'Gaijin Entertainment'}
# {'Game-title': 'Brainpipe: A Plunge to Unhumanity', 'Publisher': 'Shrapnel Games'}
# {'Game-title': 'Estranged: Act I', 'Publisher': 'Alan Edwardes'}
# {'Game-title': 'Planets Under Attack', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Comit in Krater Returns', 'Publisher': 'LunarCore Games LLC'}
# {'Game-title': 'Batman: Arkham Knight - 2008 Movie Batman Skin', 'Publisher': 'Warner Bros. Interactive Entertainment'}
# {'Game-title': 'Dungeon Defenders Eternity', 'Publisher': 'Nom Nom Games'}
# {'Game-title': 'Myth: The Fallen Lords', 'Publisher': 'Bungie'}
# {'Game-title': 'Pro Evolution Soccer 2014', 'Publisher': 'Konami'}
# {'Game-title': 'Star Trek Online', 'Publisher': 'Perfect World Entertainment'}
# {'Game-title': 'Aliens vs. Predator', 'Publisher': 'Sega'}
# {'Game-title': 'Blood Bowl 2', 'Publisher': 'Focus Entertainment'}
# {'Game-title': 'F1 2013', 'Publisher': 'Codemasters'}
# {'Game-title': 'F1 2015', 'Publisher': 'Codemasters'}
# {'Game-title': 'Hitman 2: Silent Assassin', 'Publisher': 'Eidos Interactive'}
# {'Game-title': 'Karate Master 2 Knock Down Blow', 'Publisher': 'Milestone'}
# {'Game-title': 'Lucius II', 'Publisher': 'Shiver Games'}
# {'Game-title': 'Mafia', 'Publisher': 'Gathering of Developers'}
# {'Game-title': 'Mount & Blade: With Fire and Sword', 'Publisher': 'Paradox Interactive'}
# {'Game-title': 'NBA 2K13', 'Publisher': '2K Sports'}
# {'Game-title': 'Project CARS Go', 'Publisher': 'Gamevil'}
# {'Game-title': '007: Quantum of Solace', 'Publisher': 'Activision'}
# {'Game-title': 'Railroad Tycoon 3', 'Publisher': 'Gathering of Developers'}
# {'Game-title': 'RollerCoaster Tycoon 3: Platinum', 'Publisher': 'Aspyr Media'}
# {'Game-title': 'Ryse: Son of Rome', 'Publisher': 'Microsoft Studios'}
# {'Game-title': 'Sherlock Holmes: Nemesis', 'Publisher': 'Focus Entertainment'}
# {'Game-title': 'Sherlock Holmes Versus Jack the Ripper', 'Publisher': 'Focus Entertainment'}
# {'Game-title': 'Sniper Elite III', 'Publisher': '505 Games'}
# {'Game-title': 'Spore', 'Publisher': 'Electronic Arts'}
# {'Game-title': 'Star Wars: Jedi Knight - Jedi Academy', 'Publisher': 'Activision'}
# {'Game-title': 'Take on Helicopters', 'Publisher': 'Bohemia Interactive'}
# {'Game-title': 'The Testament of Sherlock Holmes', 'Publisher': 'Atlus'}
# {'Game-title': "Tom Clancy's Ghost Recon: Future Soldier / Tom Clancy's Ghost Recon: Advanced Warfighter 2", 'Publisher': 'Publisher not found'}
# {'Game-title': "Tom Clancy's Splinter Cell: Conviction", 'Publisher': 'Ubisoft Entertainment'}
# {'Game-title': 'Wargame: Red Dragon', 'Publisher': 'Eugen Systems'}
# {'Game-title': 'Watch Dogs + Watch Dogs 2 Double Pack', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Way of the Samurai 4', 'Publisher': 'Spike'}
# {'Game-title': 'World of Guns: Gun Disassembly', 'Publisher': 'Noble Empire Corp.'}
# {'Game-title': 'Blackguards', 'Publisher': 'Daedalic Entertainment'}
# {'Game-title': 'Dead State', 'Publisher': 'DoubleBear Productions'}
# {'Game-title': 'Football Manager 2009', 'Publisher': 'Sega'}
# {'Game-title': 'Football Manager 2013', 'Publisher': 'Sega'}
# {'Game-title': 'Football Manager 2014', 'Publisher': 'Sega'}
# {'Game-title': 'Football Manager 2015', 'Publisher': 'Sega'}
# {'Game-title': 'Football Manager 2016', 'Publisher': 'Sega Games'}
# {'Game-title': 'Silent Storm: Sentinels', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Insurgency: Modern Infantry Combat', 'Publisher': 'New World Interactive'}
# {'Game-title': "Back to the Future: The Game - Episode 1: It's About Time", 'Publisher': 'Telltale Games'}
# {'Game-title': 'Double Dragon Neon', 'Publisher': 'Midnight City'}
# {'Game-title': 'FlatOut: Ultimate Carnage', 'Publisher': 'Empire Interactive'}
# {'Game-title': 'Half-Life 2: Update', 'Publisher': 'Filip Victor'}
# {'Game-title': 'Hotline Miami 2: Wrong Number', 'Publisher': 'Devolver Digital'}
# {'Game-title': 'Mortal Kombat: Komplete Edition', 'Publisher': 'WB Games'}
# {'Game-title': 'One Finger Death Punch', 'Publisher': 'Silver Dollar Games'}
# {'Game-title': 'Resident Evil: Operation Raccoon City', 'Publisher': 'Capcom'}
# {'Game-title': 'Trials 2: Second Edition', 'Publisher': 'RedLynx'}
# {'Game-title': "Assassin's Creed Brotherhood", 'Publisher': 'Publisher not found'}
# {'Game-title': "Baldur's Gate II: Enhanced Edition", 'Publisher': 'Beamdog'}
# {'Game-title': 'Bound By Flame', 'Publisher': 'Focus Entertainment'}
# {'Game-title': 'Company of Heroes: Opposing Fronts', 'Publisher': 'THQ'}
# {'Game-title': 'Dawn of Discovery: The Harbor', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Deus Ex: Game of the Year Edition', 'Publisher': 'Square Enix'}
# {'Game-title': 'Disciples III: Renaissance', 'Publisher': 'Kalypso Media'}
# {'Game-title': 'Divinity II: Ego Draconis', 'Publisher': 'Larian Studios'}
# {'Game-title': 'Dungeon Siege III', 'Publisher': 'Square Enix'}
# {'Game-title': 'Endless Space: Definitive Edition', 'Publisher': 'Sega'}
# {'Game-title': 'Fable Anniversary', 'Publisher': 'Microsoft Studios'}
# {'Game-title': 'Fallen Enchantress', 'Publisher': 'Stardock'}
# {'Game-title': 'Grand Ages: Rome', 'Publisher': 'Kalypso Media'}
# {'Game-title': 'King Arthur: The Role-Playing Wargame', 'Publisher': 'Paradox Interactive'}
# {'Game-title': "King's Bounty: The Legend", 'Publisher': 'E-Frontier'}
# {'Game-title': 'Kingdoms of Amalur: Reckoning', 'Publisher': '38 Studios'}
# {'Game-title': 'Knights of Honor', 'Publisher': 'Paradox Interactive'}
# {'Game-title': 'Men of War: Assault Squad', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Might & Magic X: Legacy', 'Publisher': 'Publisher not found'}
# {'Game-title': 'NBA 2K14', 'Publisher': '2K Sports'}
# {'Game-title': 'NBA 2K15', 'Publisher': '2K Sports'}
# {'Game-title': 'NBA 2K16', 'Publisher': '2K Sports'}
# {'Game-title': "Nobunaga's Ambition: Sphere of Influence", 'Publisher': 'Koei Tecmo Games'}
# {'Game-title': 'Pro Evolution Soccer 2015', 'Publisher': 'Konami'}
# {'Game-title': 'Rebel Galaxy', 'Publisher': 'Double Damage Games'}
# {'Game-title': 'Star Wars: The Force Unleashed - Ultimate Sith Edition', 'Publisher': 'LucasArts'}
# {'Game-title': 'Starpoint Gemini 2', 'Publisher': 'Iceberg Interactive'}
# {'Game-title': 'The Guild 2: Renaissance', 'Publisher': 'THQ Nordic'}
# {'Game-title': 'The Settlers 7: Paths to a Kingdom - Gold Edition', 'Publisher': 'Ubisoft Entertainment'}
# {'Game-title': 'Two Worlds: Epic Edition', 'Publisher': 'TopWare Interactive'}
# {'Game-title': 'X3: Albion Prelude', 'Publisher': 'Virtual Programming'}
# {'Game-title': 'X3: Terran Conflict', 'Publisher': 'Deep Silver'}
# {'Game-title': 'Xenonauts', 'Publisher': 'Goldhawk Interactive'}
# {'Game-title': 'Bunch of Heroes', 'Publisher': 'NGD Studios'}
# {'Game-title': 'Altitude', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Chime', 'Publisher': 'OneBigGame'}
# {'Game-title': 'Gunpoint', 'Publisher': 'Suspicious Developments'}
# {'Game-title': 'Magic: The Gathering - Duels of the Planeswalkers 2012', 'Publisher': 'Wizards of the Coast LLC'}
# {'Game-title': 'Runaway: A Road Adventure', 'Publisher': 'Dinamic Multimedia'}
# {'Game-title': 'S.T.A.L.K.E.R.: Call of Pripyat', 'Publisher': 'GSC World Publishing'}
# {'Game-title': 'S.T.A.L.K.E.R.: Clear Sky', 'Publisher': 'Deep Silver'}
# {'Game-title': 'Shadowgrounds', 'Publisher': 'Frozenbyte'}
# {'Game-title': 'Shadowgrounds Survivor', 'Publisher': 'Linux Game Publishing'}
# {'Game-title': 'Shattered Horizon', 'Publisher': 'Futuremark'}
# {'Game-title': 'The Dream Machine', 'Publisher': 'The Sleeping Machine'}
# {'Game-title': 'The Secret World', 'Publisher': 'Electronic Arts'}
# {'Game-title': 'Arcania: Gothic 4', 'Publisher': 'DreamCatcher Interactive'}
# {'Game-title': "Deus Ex: Human Revolution - Director's Cut", 'Publisher': 'Square Enix'}
# {'Game-title': 'Devilian', 'Publisher': 'Trion Worlds'}
# {'Game-title': 'Enslaved: Odyssey to the West Premium Edition', 'Publisher': 'Bandai Namco Entertainment'}
# {'Game-title': 'Go All Out: Free to Play', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Homefront: The Revolution', 'Publisher': 'Deep Silver'}
# {'Game-title': 'Warhammer 40,000: Dawn of War - Winter Assault', 'Publisher': 'THQ'}
# {'Game-title': 'Warhammer 40,000: Dawn of War - Game of the Year Edition', 'Publisher': 'Publisher not found'}
# {'Game-title': 'F.E.A.R. Extraction Point', 'Publisher': 'Vivendi Universal Games'}
# {'Game-title': 'F.E.A.R. Perseus Mandate', 'Publisher': 'Sierra Entertainment'}
# {'Game-title': 'Painkiller: Recurring Evil', 'Publisher': 'Nordic Games Publishing'}
# {'Game-title': 'Quake 4', 'Publisher': 'id Software'}
# {'Game-title': 'Rocksmith+', 'Publisher': 'Ubisoft Entertainment'}
# {'Game-title': 'Thinking with Time Machine', 'Publisher': 'SignHead Studio'}
# {'Game-title': '4 Elements', 'Publisher': 'Playrix Entertainment'}
# {'Game-title': '9 Clues: The Secret of Serpent Creek', 'Publisher': 'G5 Entertainment'}
# {'Game-title': 'Abyss: The Wraiths of Eden', 'Publisher': 'G5 Entertainment'}
# {'Game-title': 'Alchemy Mysteries: Prague Legends', 'Publisher': 'JetDogs Studios'}
# {'Game-title': 'Alice: Madness Returns', 'Publisher': 'Electronic Arts'}
# {'Game-title': 'And Yet It Moves', 'Publisher': 'DeNA Co., Ltd.'}
# {'Game-title': 'Anodyne', 'Publisher': 'Analgesic Productions'}
# {'Game-title': 'Antichamber', 'Publisher': 'Demruth'}
# {'Game-title': 'Atom Zombie Smasher', 'Publisher': 'Blendo Games'}
# {'Game-title': 'Aura: Fate of the Ages', 'Publisher': 'Nordic Games Publishing'}
# {'Game-title': 'Bastion', 'Publisher': 'WB Games'}
# {'Game-title': 'CID: The Dummy', 'Publisher': 'Oxygen Games'}
# {'Game-title': 'Cargo! The Quest for Gravity', 'Publisher': 'bitComposer Games'}
# {'Game-title': 'Clockwork Tales: Of Glass and Ink', 'Publisher': 'Artifex Mundi'}
# {'Game-title': 'Contagion', 'Publisher': 'Monochrome LLC'}
# {'Game-title': 'Cryostasis', 'Publisher': '505 Games'}
# {'Game-title': 'Deponia: The Complete Journey', 'Publisher': 'Daedalic Entertainment'}
# {'Game-title': 'Eets: Chowdown', 'Publisher': 'Microsoft Game Studios'}
# {'Game-title': 'Ghost Master', 'Publisher': 'Empire Interactive'}
# {'Game-title': 'Goat Simulator', 'Publisher': 'Coffee Stain Studios'}
# {'Game-title': 'Grim Legends: The Forsaken Bride', 'Publisher': 'Artifex Mundi'}
# {'Game-title': 'Hector: Badge of Carnage! - Episode 1', 'Publisher': 'Straandlooper Animation'}
# {'Game-title': 'Hidden Object Bundle 4 in 1', 'Publisher': 'Alawar Entertainment'}
# {'Game-title': 'Indigo Prophecy', 'Publisher': 'Atari, Inc.'}
# {'Game-title': 'Insanely Twisted Shadow Planet', 'Publisher': 'Microsoft Studios'}
# {'Game-title': 'Lara Croft and the Guardian of Light', 'Publisher': 'Square Enix'}
# {'Game-title': "MacGuffin's Curse", 'Publisher': 'Brawsome'}
# {'Game-title': 'Monaco 2', 'Publisher': 'Humble Games'}
# {'Game-title': "Monkey Island 2 Special Edition: LeChuck's Revenge", 'Publisher': 'LucasArts'}
# {'Game-title': 'Nidhogg 2', 'Publisher': 'Messhof'}
# {'Game-title': 'Nightmares from the Deep: Cursed Heart', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Obulis', 'Publisher': 'IonFX'}
# {'Game-title': 'Peggle Nights', 'Publisher': 'PopCap Games'}
# {'Game-title': 'Penumbra: Black Plague - Gold Edition', 'Publisher': 'Frictional Games'}
# {'Game-title': 'Penumbra: Overture', 'Publisher': 'Paradox Interactive'}
# {'Game-title': 'Poker Night at the Inventory', 'Publisher': 'Telltale Games'}
# {'Game-title': 'Puzzle Agent', 'Publisher': 'Telltale Games'}
# {'Game-title': 'Puzzle Agent 2', 'Publisher': 'Telltale Games'}
# {'Game-title': 'Puzzler World 2', 'Publisher': 'Ideas Pad'}
# {'Game-title': 'Resident Evil 5', 'Publisher': 'Capcom'}
# {'Game-title': 'Rocketbirds: Hardboiled Chicken', 'Publisher': 'Reverb Publishing'}
# {'Game-title': 'Saints Row 2', 'Publisher': 'THQ'}
# {'Game-title': 'Sam & Max: Save the World - Episode 1: Culture Shock', 'Publisher': 'Telltale Games'}
# {'Game-title': 'Sam & Max: Save the World - Episode 4: Abe Lincoln Must Die!', 'Publisher': 'Telltale Games'}
# {'Game-title': 'Sam & Max: Save the World - Episode 5: Reality 2.0', 'Publisher': 'Telltale Games'}
# {'Game-title': 'Sam & Max: Save the World - Episode 6: Bright Side of the Moon', 'Publisher': 'Telltale Games'}
# {'Game-title': 'Shatter', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Shoppe Keep', 'Publisher': 'Excalibur Games'}
# {'Game-title': 'Singularity', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Sinister City', 'Publisher': 'JetDogs Studios'}
# {'Game-title': 'Surgeon Simulator 2', 'Publisher': 'Bossa Studios'}
# {'Game-title': 'Tales of Monkey Island: Chapter 3 - Lair of the Leviathan', 'Publisher': 'Telltale Games'}
# {'Game-title': 'The Book of Unwritten Tales', 'Publisher': 'HMH Interactive'}
# {'Game-title': 'The Elder Scrolls III: Morrowind', 'Publisher': 'ZeniMax Media'}
# {'Game-title': 'The Jackbox Party Pack', 'Publisher': 'Jackbox Games'}
# {'Game-title': 'The Maw', 'Publisher': 'Twisted Pixel'}
# ...
# {'Game-title': 'Teddy Floppy Ear: Mountain Adventure', 'Publisher': 'Forever Entertainment S. A.'}
# {'Game-title': 'Teddy Floppy Ear: The Race', 'Publisher': 'Forever Entertainment S. A.'}
# {'Game-title': 'The 39 Steps', 'Publisher': 'Faber and Faber'}
# {'Game-title': 'The Adventures of Mr. Bobley', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Woodle Tree Adventures', 'Publisher': 'Chubby Pixel'}
# {'Game-title': 'The Defenders: The Second Wave', 'Publisher': 'FallenMaster'}
# {'Game-title': 'The Lady', 'Publisher': 'Publisher not found'}
# {'Game-title': 'The Nightmare Cooperative', 'Publisher': 'Publisher not found'}
# {'Game-title': 'The Undying Plague', 'Publisher': 'Pixel Theory'}
# {'Game-title': 'Tidalis', 'Publisher': 'Headup Games'}
# {'Game-title': 'Time Mysteries: Inheritance - Remastered', 'Publisher': 'Artifex Mundi'}
# {'Game-title': 'Treeker: The Lost Glasses', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Triple Town', 'Publisher': 'Spry Fox LLC'}
# {'Game-title': 'Vintage Year', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Waveform', 'Publisher': 'Eden Industries'}
# {'Game-title': 'You Must Build A Boat', 'Publisher': 'EightyEightGames'}
# {'Game-title': 'Yury', 'Publisher': 'Cubic Pie'}
# {'Game-title': 'Dragon Ball Z: Super Butouden 3', 'Publisher': 'Bandai'}
# {'Game-title': 'Zombie Zoeds', 'Publisher': 'Publisher not found'}
# {'Game-title': 'NASCAR: The Game 2013', 'Publisher': 'Eutechnyx'}
# {'Game-title': 'The Amazing Spider-Man 2', 'Publisher': 'Gameloft'}
# {'Game-title': 'NeoTokyo', 'Publisher': 'NEOTOKYO [MOD]'}
# {'Game-title': 'The Incredible Adventures of Van Helsing III', 'Publisher': 'NeoCore Games'}
# {'Game-title': 'Better Late Than Dead', 'Publisher': 'Excalibur Games'}
# {'Game-title': 'Wildlife Park 3', 'Publisher': 'b-alive'}
# {'Game-title': 'Amnesia: Memories', 'Publisher': 'Idea Factory'}
# {'Game-title': "Anna's Quest", 'Publisher': 'Daedalic Entertainment'}
# {'Game-title': 'Crystals of Time', 'Publisher': 'Exosyphen Studios'}
# {'Game-title': 'Fading Hearts', 'Publisher': 'Sakura River Interactive'}
# {'Game-title': 'Super Chibi Knight', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Emily is Away', 'Publisher': 'Kyle Seeley'}
# {'Game-title': "Cabela's Hunting Expeditions", 'Publisher': 'Activision'}
# {'Game-title': 'Alex Hunter: Lord of the Mind', 'Publisher': 'Alawar Entertainment'}
# {'Game-title': 'Ballad of Solar', 'Publisher': 'Alawar'}
# {'Game-title': 'Demon Hunter: Chronicles from Beyond', 'Publisher': 'Artifex Mundi'}
# {'Game-title': 'Enigmatis 2: The Mists of Ravenwood', 'Publisher': 'Artifex Mundi'}
# {'Game-title': 'Fall of the New Age: Premium Edition', 'Publisher': 'PlayRIX'}
# {'Game-title': "Ghost Encounters: Deadwood - Collector's Edition", 'Publisher': 'Anarchy Enterprises'}
# {'Game-title': 'Grim Legends 2: Song of the Dark Swan', 'Publisher': 'Artifex Mundi'}
# {'Game-title': 'Mountain Crime: Requital', 'Publisher': 'Alawar Entertainment'}
# {'Game-title': 'Nightmares from the Deep 3: Davy Jones', 'Publisher': 'Artifex Mundi'}
# {'Game-title': "Portal of Evil: Stolen Runes - Collector's Edition", 'Publisher': 'Publisher not found'}
# {'Game-title': "The Musketeers: Victoria's Quest", 'Publisher': 'Buka Entertainment'}
# {'Game-title': 'Time Mysteries 2: The Ancient Spectres', 'Publisher': 'Artifex Mundi'}
# {'Game-title': 'Time Mysteries 3: The Final Enigma', 'Publisher': 'Artifex Mundi'}
# {'Game-title': "Weather Lord: The Successor's Path", 'Publisher': 'Buka Entertainment'}
# {'Game-title': 'Guns n Zombies', 'Publisher': 'Krealit'}
# {'Game-title': 'FortressCraft Evolved!', 'Publisher': 'Digital Tribe'}
# {'Game-title': 'Dream of Mirror Online', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Hack, Slash, Loot', 'Publisher': 'David Williamson'}
# {'Game-title': 'Watchmen: The End is Nigh Part 2', 'Publisher': 'WB Games'}
# {'Game-title': 'Run Fire', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Airport Madness: World Edition', 'Publisher': 'Big Fat Simulations Inc.'}
# {'Game-title': 'Nostradamus: The Last Prophecy', 'Publisher': 'Anuman'}
# {'Game-title': 'TerraTech', 'Publisher': 'Payload Studios'}
# {'Game-title': 'The Impossible Game', 'Publisher': 'FlukeDude'}
# {'Game-title': 'Might & Magic: Heroes Online', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Commandos 2: Men of Courage', 'Publisher': 'Eidos Interactive'}
# {'Game-title': 'Stronghold Legends', 'Publisher': '2K Games'}
# {'Game-title': 'Anomaly: Warzone Earth - Mobile Campaign', 'Publisher': '11 bit studios'}
# {'Game-title': 'Apollo4x', 'Publisher': 'Publisher not found'}
# {'Game-title': "Buzz Aldrin's Space Program Manager", 'Publisher': 'Polar Motion'}
# {'Game-title': 'Defy Gravity', 'Publisher': 'Fish Factory Games'}
# {'Game-title': 'TV Empire Tycoon', 'Publisher': 'Codigames'}
# {'Game-title': 'Epigenesis', 'Publisher': 'Dead Shark Triplepunch'}
# {'Game-title': 'Escape Machines', 'Publisher': 'Back To Basics Gaming'}
# {'Game-title': 'FootLOL: Epic Fail League', 'Publisher': 'HeroCraft'}
# {'Game-title': 'GamersGoMakers', 'Publisher': 'gnifrebel Games UG'}
# {'Game-title': 'Grimind', 'Publisher': 'KISS ltd'}
# {'Game-title': 'Hollywood Visionary', 'Publisher': 'Choice of Games'}
# {'Game-title': 'RPG Tycoon', 'Publisher': 'GSProductions Ltd.'}
# {'Game-title': 'Saturday Morning RPG', 'Publisher': 'Joystick Labs, LLC'}
# {'Game-title': 'Showtime!', 'Publisher': 'KISS ltd'}
# {'Game-title': 'Spooky Cats', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Sunrider Academy', 'Publisher': 'Sekai Project'}
# {'Game-title': 'Super Motherload', 'Publisher': 'XGen Studios'}
# {'Game-title': 'The Lost Crown', 'Publisher': 'Iceberg Interactive'}
# {'Game-title': 'Flesh Eaters', 'Publisher': 'Back To Basics Gaming'}
# {'Game-title': 'Heroes of Scene', 'Publisher': 'Publisher not found'}
# {'Game-title': 'NotTheNameWeWanted', 'Publisher': 'Publisher not found'}
# {'Game-title': '60 Seconds Santa Run', 'Publisher': 'Coolmath Games'}
# {'Game-title': 'Qvadriga', 'Publisher': 'Slitherine Ltd.'}
# {'Game-title': 'Rulers of Nations', 'Publisher': 'Eversim'}
# {'Game-title': "NASCAR '14", 'Publisher': 'Deep Silver'}
# {'Game-title': 'War Theatre', 'Publisher': 'Arcade Distillery'}
# {'Game-title': 'Rake', 'Publisher': 'Konsordo'}
# {'Game-title': 'Rising World', 'Publisher': 'KISS ltd'}
# {'Game-title': 'Sakura Angels', 'Publisher': 'Publisher not found'}
# {'Game-title': "Day One: Garry's Incident", 'Publisher': 'Wild Games Studio'}
# {'Game-title': 'Blitzkrieg Anthology', 'Publisher': 'Nival'}
# {'Game-title': 'Panzer Tactics HD', 'Publisher': 'THQ Nordic'}
# {'Game-title': 'Delta Force 2', 'Publisher': 'NovaLogic'}
# {'Game-title': "Memoir '44 Online", 'Publisher': 'Days of Wonder'}
# {'Game-title': 'Nancy Drew: Curse of Blackmoor Manor', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Nancy Drew: Secret of the Scarlet Hand', 'Publisher': 'Her Interactive'}
# {'Game-title': 'Nancy Drew: Secrets Can Kill', 'Publisher': 'DreamCatcher Games'}
# {'Game-title': 'Nancy Drew: The White Wolf of Icicle Creek', 'Publisher': 'Her Interactive'}
# {'Game-title': 'Fast & Furious: Showdown', 'Publisher': 'Activision'}
# {'Game-title': 'Towtruck Simulator 2015', 'Publisher': 'United Independent Entertainment GmbH'}
# {'Game-title': 'Starwhal', 'Publisher': 'Breakfall'}
# {'Game-title': 'Amazing World', 'Publisher': 'Ganz'}
# {'Game-title': 'Pro Rugby Manager 2015', 'Publisher': '505 Games'}
# {'Game-title': 'The Guild: Gold Edition', 'Publisher': 'THQ Nordic'}
# {'Game-title': 'Need For Madness', 'Publisher': 'Publisher not found'}
# {'Game-title': "Akiba's Trip: Undead & Undressed", 'Publisher': 'XSEED Games'}
# {'Game-title': 'Chocolatier: Decadence by Design', 'Publisher': 'Big Splash Games, LLC'}
# {'Game-title': 'Cultures: Northland', 'Publisher': 'Funatics Development'}
# {'Game-title': "Jets'n'Guns Gold", 'Publisher': 'Rake in Grass'}
# {'Game-title': 'Gunscape', 'Publisher': 'Blowfish Studios'}
# {'Game-title': 'Navy Field 2 : Conqueror of the Ocean', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Timberman', 'Publisher': 'Digital Melody'}
# {'Game-title': 'Party Hard', 'Publisher': 'tinyBuild'}
# {'Game-title': 'Gurumin: A Monstrous Adventure', 'Publisher': 'Mastiff'}
# {'Game-title': 'Blood: One Unit Whole Blood', 'Publisher': 'Atari Interactive'}
# {'Game-title': 'Painkiller: Black Edition', 'Publisher': 'Nordic Games Publishing'}
# {'Game-title': 'Gaokao.Love.100Days', 'Publisher': 'NVLMaker'}
# {'Game-title': 'Reversion: The Escape -1st Chapter', 'Publisher': '3f Interactive'}
# {'Game-title': 'Heroes of SoulCraft', 'Publisher': 'MobileBits'}
# {'Game-title': "Steins;Gate: My Darling's Embrace", 'Publisher': '5pb.'}
# {'Game-title': 'Mechanic Escape', 'Publisher': 'Plug In Digital'}
# {'Game-title': 'Karos Returns', 'Publisher': 'RedFox Games'}
# {'Game-title': 'Bedlam 2: Absolute Bedlam', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Blue Rose Reprise', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Higurashi When They Cry Hou: Ch.1 Onikakushi', 'Publisher': 'MangaGamer'}
# {'Game-title': 'Retention', 'Publisher': 'Sometimes You'}
# {'Game-title': 'The Clans - Saga of the Twins', 'Publisher': 'Publisher not found'}
# {'Game-title': 'X-Note', 'Publisher': 'Zeiva Inc Production'}
# {'Game-title': 'E.V.O. : Search for Eden', 'Publisher': 'Enix America Corporation'}
# {'Game-title': 'MXGP 2020: The Official Motocross Videogame', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Duck Dynasty', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Sky Heroes', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Imperial Glory', 'Publisher': 'Feral Interactive'}
# {'Game-title': 'Creeper World 3: Arc Eternal', 'Publisher': 'Knuckle Cracker'}
# {'Game-title': 'Real Boxing', 'Publisher': 'Vivid Games'}
# {'Game-title': 'Seduce Me the Otome', 'Publisher': 'Michaela Laws'}
# {'Game-title': 'City of Steam: Arkadia', 'Publisher': 'Mechanist Games'}
# {'Game-title': 'Monochroma', 'Publisher': 'Nowhere Studios'}
# {'Game-title': 'Commander Keen Complete Pack', 'Publisher': 'Apogee Software'}
# {'Game-title': "Chris Sawyer's Locomotion", 'Publisher': 'Atari, Inc.'}
# {'Game-title': 'Containment: The Zombie Puzzler', 'Publisher': 'Bootsnake Games'}
# {'Game-title': 'Reprisal Universe', 'Publisher': 'electrolyte'}
# {'Game-title': 'Golden Rush', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Dig or Die', 'Publisher': 'Gaddy Games'}
# {'Game-title': 'Mainland', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Soccer Manager 2015', 'Publisher': 'Publisher not found'}
# {'Game-title': 'East India Company: Gold', 'Publisher': 'TopWare Interactive'}
# {'Game-title': 'Eldevin', 'Publisher': 'Hunted Cow Studios'}
# {'Game-title': 'CrimeCraft: GangWars', 'Publisher': 'Vogster Entertainment'}
# {'Game-title': 'DCS World', 'Publisher': 'Eagle Dynamics'}
# {'Game-title': 'Back to Dinosaur Island', 'Publisher': 'Crytek'}
# {'Game-title': 'Industry Giant II', 'Publisher': 'Fancy Bytes'}
# {'Game-title': 'The Witcher: Adventure Game', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Tree of Life', 'Publisher': 'Publisher not found'}
# {'Game-title': 'One on One: Dr. J vs. Larry Bird', 'Publisher': 'Ariolasoft'}
# {'Game-title': 'Doodle God Blitz: Doodle Devil', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Elite: Dangerous - Horizons', 'Publisher': 'Frontier Developments'}
# {'Game-title': 'WRC 5 FIA World Rally Championship', 'Publisher': 'Plug In Digital'}
# {'Game-title': 'The Ultimate Doom', 'Publisher': 'KippyKip'}
# {'Game-title': 'Hamlet or the Last Game without MMORPG Features, Shaders and Product Placement', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Cosmophony', 'Publisher': 'Frogames'}
# {'Game-title': 'Decay: The Mare', 'Publisher': 'Daedalic Entertainment'}
# {'Game-title': 'Wario Land: Super Mario Land 3', 'Publisher': 'Nintendo'}
# {'Game-title': 'Lovely Planet', 'Publisher': 'tinyBuild'}
# {'Game-title': 'World of Mixed Martial Arts 3', 'Publisher': 'Viva Media'}
# {'Game-title': 'Deathtrap', 'Publisher': 'NeoCore Games'}
# {'Game-title': 'Hexen II', 'Publisher': 'id Software'}
# {'Game-title': 'Defend Your Life', 'Publisher': 'Alda Games'}
# {'Game-title': 'Majesty: Gold Edition', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Don Bradman Cricket 14', 'Publisher': 'Tru Blu Entertainment'}
# {'Game-title': 'Nightbanes', 'Publisher': 'Headup Games'}
# {'Game-title': 'Warmode', 'Publisher': 'Publisher not found'}
# {'Game-title': 'CastleMiner Z', 'Publisher': 'DigitalDNA Games LLC'}
# {'Game-title': "Assassin's Creed Rogue", 'Publisher': 'Publisher not found'}
# {'Game-title': 'One Piece: Pirate Warriors 3', 'Publisher': 'Bandai Namco Entertainment'}
# {'Game-title': 'Doom II + Master Levels', 'Publisher': 'GT Interactive Software'}
# {'Game-title': 'MoW: Face Off M', 'Publisher': 'ISOTX'}
# {'Game-title': 'Warhammer Quest', 'Publisher': 'Chilled Mouse'}
# {'Game-title': 'Steredenn', 'Publisher': 'Plug In Digital'}
# {'Game-title': 'Eastside Hockey Manager', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Franchise Hockey Manager 2', 'Publisher': 'Out Of The Park Developments'}
# {'Game-title': 'Ship Simulator: Maritime Search and Rescue', 'Publisher': 'rondomedia Marketing & Vertriebs GmbH'}
# {'Game-title': 'Jagged Alliance: Flashback', 'Publisher': 'Full Control'}
# {'Game-title': 'Sacred Gold', 'Publisher': 'Strategy First'}
# {'Game-title': 'Championship Manager 2010', 'Publisher': 'Eidos Interactive'}
# {'Game-title': 'Apotheon Arena', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Warside', 'Publisher': 'Lavabird'}
# {'Game-title': 'UberStrike', 'Publisher': 'Cmune'}
# {'Game-title': 'Eternal Senia', 'Publisher': 'Sanctum Games Limited'}
# {'Game-title': 'Audition Online', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Autocraft', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Moonbase Alpha', 'Publisher': 'NASA'}
# {'Game-title': "Randal's Monday", 'Publisher': 'Daedalic Entertainment'}
# {'Game-title': 'Star Traders: 4X Empires', 'Publisher': 'Trese Brothers'}
# {'Game-title': 'Rugby League Team Manager 2015', 'Publisher': 'Alternative Software Ltd'}
# {'Game-title': 'Captain Forever Remix', 'Publisher': 'Pixelsaurus Games'}
# {'Game-title': 'Block Story', 'Publisher': 'MindBlocks Studio, LLC'}
# {'Game-title': 'The Settlers Online', 'Publisher': 'Publisher not found'}
# {'Game-title': "Nobunaga's Ambition: Kakushin with Power Up Kit", 'Publisher': 'Publisher not found'}
# {'Game-title': 'Warrior Kings: Battles', 'Publisher': 'Strategy First'}
# {'Game-title': 'Firefighters 2014', 'Publisher': 'rondomedia Marketing & Vertriebs GmbH'}
# {'Game-title': 'Bargain Basement', 'Publisher': 'Publisher not found'}
# {'Game-title': 'CubeGun', 'Publisher': 'candyrocketstudio'}
# {'Game-title': 'Metal War Online: Retribution', 'Publisher': 'Publisher not found'}
# {'Game-title': 'Hook', 'Publisher': 'Rainbow Train'}
# {'Game-title': 'Missing Translation', 'Publisher': 'GamesBoosters'}
# {'Game-title': 'Destination Sol', 'Publisher': 'Movingblocks'}
# {'Game-title': 'Cossacks: European Wars', 'Publisher': 'Strategy First'}
# {'Game-title': 'Close Your Eyes', 'Publisher': 'Publisher not found'}
# {'Game-title': 'The Sims 4: Bust the Dust Kit', 'Publisher': 'Electronic Arts'}
# {'Game-title': 'Sigils of Elohim', 'Publisher': 'Devolver Digital'}
# {'Game-title': 'Secret Files: Tunguska', 'Publisher': 'Deep Silver'}
# {'Game-title': 'SimpleRockets', 'Publisher': 'Jundroo, LLC'}
#                            Game-title            Publisher
# 0                         Alien Swarm                Valve
# 1     Cities: Skylines - Green Cities  Paradox Interactive
# 2           Deus Ex: Human Revolution          Square Enix
# 3                 Portal 2: In Motion  Publisher not found
# 4       Age of Empires II: HD Edition    Microsoft Studios
# ...                               ...                  ...
# 2606                  Close Your Eyes  Publisher not found
# 2607    The Sims 4: Bust the Dust Kit      Electronic Arts
# 2608                 Sigils of Elohim     Devolver Digital
# 2609           Secret Files: Tunguska          Deep Silver
# 2610                    SimpleRockets         Jundroo, LLC
#
# [2611 rows x 2 columns]

# %%
filter_unprocessed_df = genres_info[genres_info['Publisher'].isin(['Publisher not found','API Error'])]
filter_unprocessed_df.to_csv('filter_unprocessed_df.csv', index=None)
filter_unprocessed_df
# Out:
#                                            Game-title            Publisher
# 3                                 Portal 2: In Motion  Publisher not found
# 10                    Counter-Strike Global Offensive  Publisher not found
# 33                                      Borderlands 2  Publisher not found
# 36         Bulletstorm: Duke Nukem's Bulletstorm Tour  Publisher not found
# 41                  Dark Souls Prepare to Die Edition  Publisher not found
# ...                                               ...                  ...
# 2595                              The Settlers Online  Publisher not found
# 2596  Nobunaga's Ambition: Kakushin with Power Up Kit  Publisher not found
# 2599                                 Bargain Basement  Publisher not found
# 2601                    Metal War Online: Retribution  Publisher not found
# 2606                                  Close Your Eyes  Publisher not found
#
# [393 rows x 2 columns]

# %%
filter_processed_df = pd.read_csv("filter_processed_df.csv")
filter_processed_df
# Out:
#                                           Game-title  \
# 0                                Portal 2: In Motion
# 1                    Counter-Strike Global Offensive
# 2                                      Borderlands 2
# 3         Bulletstorm: Duke Nukem's Bulletstorm Tour
# 4                  Dark Souls Prepare to Die Edition
# ..                                               ...
# 387                              The Settlers Online
# 388  Nobunaga's Ambition: Kakushin with Power Up Kit
# 389                                 Bargain Basement
# 390                    Metal War Online: Retribution
# 391                                  Close Your Eyes
#
#                       Publisher
# 0                         Valve
# 1                         Valve
# 2                      2K Games
# 3               Electronic Arts
# 4    Bandai Namco Entertainment
# ..                          ...
# 387                     Ubisoft
# 388                  Koei Tecmo
# 389                         NaN
# 390                     Netease
# 391               Yai Gameworks
#
# [392 rows x 2 columns]

# %%
test_genres_info = genres_info.copy()

merged_df = test_genres_info.merge(
    filter_processed_df[['Game-title', 'Publisher']],
    on='Game-title',
    how='left',
    suffixes=('', '_filtered')
)

# Define a function to decide when to replace Publisher
def update_publisher(original, updated):
    if original == "Publisher not found" or original == "API Error":
        return updated
    else:
        return original

# Apply the function row-wise
merged_df['Publisher'] = merged_df.apply(
    lambda row: update_publisher(row['Publisher'], row['Publisher_filtered']),
    axis=1
)

# Drop the extra Publisher column
merged_df.drop(columns=['Publisher_filtered'], inplace=True)

merged_df
# Out:
#                            Game-title            Publisher
# 0                         Alien Swarm                Valve
# 1     Cities: Skylines - Green Cities  Paradox Interactive
# 2           Deus Ex: Human Revolution          Square Enix
# 3                 Portal 2: In Motion                Valve
# 4       Age of Empires II: HD Edition    Microsoft Studios
# ...                               ...                  ...
# 2612                  Close Your Eyes        Yai Gameworks
# 2613    The Sims 4: Bust the Dust Kit      Electronic Arts
# 2614                 Sigils of Elohim     Devolver Digital
# 2615           Secret Files: Tunguska          Deep Silver
# 2616                    SimpleRockets         Jundroo, LLC
#
# [2617 rows x 2 columns]

# %%
genres_info.to_csv("genres_info1212122121.csv")

# %%
game_info_df
# Out:
#                         Game-title                     genre  \
# 0                      Alien Swarm                   Shooter
# 1                  Cities Skylines                 Simulator
# 2         Deus Ex Human Revolution                   Shooter
# 3                         Portal 2                   Shooter
# 4     Age of Empires II HD Edition  Real Time Strategy (RTS)
# ...                            ...                       ...
# 2605               Close Your Eyes                    Puzzle
# 2606                   All Is Dust        Role-playing (RPG)
# 2607              Sigils of Elohim                    Puzzle
# 2608         Secret Files Tunguska           Point-and-click
# 2609                 SimpleRockets                 Simulator
#
#                                                 summary
# 0     Alien Swarm is a game and Source SDK release f...
# 1     Cities: Skylines - Green Cities is a new expan...
# 2     In Deus Ex: Human Revolution you play Adam Jen...
# 3     Get Portal™2 In Motion™, Adventure, Puzzle, Sh...
# 4     In Age of Empires II: HD Edition, fans of the ...
# ...                                                 ...
# 2605  Close Your Eyes is a puzzle horror game where ...
# 2606  Dust off the vacuum and tidy up with The Sims ...
# 2607  As if awakening from a deep sleep, you find yo...
# 2608  Unravel one of the greatest mysteries of our t...
# 2609  Design your own rocket ships. Blast off into s...
#
# [2610 rows x 3 columns]

# %%
nan_summary_games = game_info_df[game_info_df['summary'].isna()]
print(f"Number of missing values in 'summary': {nan_summary_games}")

# %%
Final_info_df = pd.merge(pivot_df, merged_df, on='Game-title', how='left')
#Final_info_df = Final_info_df.drop(columns=['genre'])

Final_info_df['Publisher'].fillna('Publisher not available', inplace=True)

Final_info_df.drop_duplicates()
# Out:
#          User-id             Game-title               Genre  personal-rating  \
# 0           5250            Alien Swarm             Shooter                3
# 1         975449            Alien Swarm             Shooter                5
# 2        1950243            Alien Swarm             Shooter                3
# 3        2259650            Alien Swarm             Shooter                2
# 4        2753525            Alien Swarm             Shooter                2
# ...          ...                    ...                 ...              ...
# 43059  287824954        Close Your Eyes              Puzzle                5
# 43060  293303005            All Is Dust  Role-playing (RPG)                5
# 43061  300248088       Sigils of Elohim              Puzzle                5
# 43062  306839937  Secret Files Tunguska     Point-and-click                5
# 43063  307846753          SimpleRockets           Simulator                5
#
#                                              description  \
# 0      Alien Swarm is a game and Source SDK release f...
# 1      Alien Swarm is a game and Source SDK release f...
# 2      Alien Swarm is a game and Source SDK release f...
# 3      Alien Swarm is a game and Source SDK release f...
# 4      Alien Swarm is a game and Source SDK release f...
# ...                                                  ...
# 43059  Close Your Eyes is a puzzle horror game where ...
# 43060  Dust off the vacuum and tidy up with The Sims ...
# 43061  As if awakening from a deep sleep, you find yo...
# 43062  Unravel one of the greatest mysteries of our t...
# 43063  Design your own rocket ships. Blast off into s...
#
#                      Publisher
# 0                        Valve
# 1                        Valve
# 2                        Valve
# 3                        Valve
# 4                        Valve
# ...                        ...
# 43059            Yai Gameworks
# 43060  Publisher not available
# 43061         Devolver Digital
# 43062  Publisher not available
# 43063             Jundroo, LLC
#
# [42539 rows x 6 columns]

# %%
Final_info_df.to_csv("Data_final_description.csv")

# %%
# Concatenate with the existing DataFrame
combined_genres_df = pd.concat([combined_genres_df, game_info_df], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Concatenate with the existing DataFrame
# ----> 2 combined_genres_df = pd.concat([combined_genres_df, game_info_df], ignore_index=True)
#
# NameError: name 'combined_genres_df' is not defined

# %%
combined_genres_df

# %%
combined_genres_df.drop_duplicates()

# %%
combined_genres_df.to_csv('game_genres.csv', index=False)

# %%
combined_genres_df = pd.read_csv('game_genres.csv')

# %%
combined_genres_df
# Out:
#                                              Game-title               Genre
# 0                                           Alien Swarm             Shooter
# 1                                       Cities Skylines           Simulator
# 2                                        Counter-Strike             Shooter
# 3                                 Counter-Strike Source             Shooter
# 4                                         Day of Defeat             Shooter
# ...                                                 ...                 ...
# 7150  Heroes Never Lose Professor Puzzler's Perplexi...              Puzzle
# 7151                                        Operation Z               Indie
# 7152                                        Retaliation           Adventure
# 7153                                           Abducted  Role-playing (RPG)
# 7154                                      SimpleRockets           Simulator
#
# [7155 rows x 2 columns]

# %%
combined_genres_df_drop_dupes = combined_genres_df.drop_duplicates()

# %%
combined_genres_df_drop_dupes.to_csv('game_genres.csv', index=False)

# %%
combined_genres_df_drop_dupes
# Out:
#                                              Game-title               Genre
# 0                                           Alien Swarm             Shooter
# 1                                       Cities Skylines           Simulator
# 2                                        Counter-Strike             Shooter
# 3                                 Counter-Strike Source             Shooter
# 4                                         Day of Defeat             Shooter
# ...                                                 ...                 ...
# 7150  Heroes Never Lose Professor Puzzler's Perplexi...              Puzzle
# 7151                                        Operation Z               Indie
# 7152                                        Retaliation           Adventure
# 7153                                           Abducted  Role-playing (RPG)
# 7154                                      SimpleRockets           Simulator
#
# [5155 rows x 2 columns]

# %%
merged_df = pd.merge(pivot_df, combined_genres_df_drop_dupes, on='Game-title', how='left')
merged_df = merged_df.drop_duplicates()

# %%
merged_df
# Out:
#           User-id                    Game-title  Playtime  Purchase  \
# 0            5250                   Alien Swarm       4.9         1
# 1            5250               Cities Skylines     144.0         1
# 2            5250                Counter-Strike       0.0         1
# 3            5250         Counter-Strike Source       0.0         1
# 4            5250                 Day of Defeat       0.0         1
# ...           ...                           ...       ...       ...
# 128799  309626088  Age of Empires II HD Edition       6.7         1
# 128800  309812026  Counter-Strike Nexon Zombies       0.0         1
# 128801  309812026                     Robocraft       0.0         1
# 128802  309824202                        Dota 2       0.7         1
# 128803  309903146                        Dota 2       0.2         1
#
#                            Genre
# 0                        Shooter
# 1                      Simulator
# 2                        Shooter
# 3                        Shooter
# 4                        Shooter
# ...                          ...
# 128799  Real Time Strategy (RTS)
# 128800           Genre not found
# 128801                   Shooter
# 128802                  Strategy
# 128803                  Strategy
#
# [128804 rows x 5 columns]

# %%
cleaned_df = merged_df[merged_df['Genre'] != 'Genre not found'].drop(['Purchase'],axis=1)

# %%
cleaned_df
# Out:
#           User-id                    Game-title  Playtime  \
# 0            5250                   Alien Swarm       4.9
# 1            5250               Cities Skylines     144.0
# 2            5250                Counter-Strike       0.0
# 3            5250         Counter-Strike Source       0.0
# 4            5250                 Day of Defeat       0.0
# ...           ...                           ...       ...
# 128798  309554670             Mitos.is The Game       5.9
# 128799  309626088  Age of Empires II HD Edition       6.7
# 128801  309812026                     Robocraft       0.0
# 128802  309824202                        Dota 2       0.7
# 128803  309903146                        Dota 2       0.2
#
#                            Genre
# 0                        Shooter
# 1                      Simulator
# 2                        Shooter
# 3                        Shooter
# 4                        Shooter
# ...                          ...
# 128798  Real Time Strategy (RTS)
# 128799  Real Time Strategy (RTS)
# 128801                   Shooter
# 128802                  Strategy
# 128803                  Strategy
#
# [114716 rows x 4 columns]

# %%
cleaned_df.to_csv("cleaned_df.csv", index=False)

# %% [markdown]
# # Deriving Ratings

# %%
df = pd.read_csv("cleaned_df.csv")

# %%
df.head()
# Out:
#    User-id             Game-title  Playtime      Genre
# 0     5250            Alien Swarm       4.9    Shooter
# 1     5250        Cities Skylines     144.0  Simulator
# 2     5250         Counter-Strike       0.0    Shooter
# 3     5250  Counter-Strike Source       0.0    Shooter
# 4     5250          Day of Defeat       0.0    Shooter

# %%
# purging game library that has less than 2 hours
df= df[(df['Playtime']>=2)]

# %%
df
# Out:
#           User-id                    Game-title  Playtime  \
# 0            5250                   Alien Swarm       4.9
# 1            5250               Cities Skylines     144.0
# 6            5250      Deus Ex Human Revolution      62.0
# 17           5250                      Portal 2      13.6
# 20          76767  Age of Empires II HD Edition      13.1
# ...           ...                           ...       ...
# 114706  309404240             Mitos.is The Game       2.2
# 114707  309404240               Team Fortress 2       2.2
# 114709  309404240                      Unturned      13.0
# 114711  309554670             Mitos.is The Game       5.9
# 114712  309626088  Age of Empires II HD Edition       6.7
#
#                            Genre
# 0                        Shooter
# 1                      Simulator
# 6                        Shooter
# 17                       Shooter
# 20      Real Time Strategy (RTS)
# ...                          ...
# 114706  Real Time Strategy (RTS)
# 114707                   Shooter
# 114709                   Shooter
# 114711  Real Time Strategy (RTS)
# 114712  Real Time Strategy (RTS)
#
# [42539 rows x 4 columns]

# %%
df['Game-title'].nunique()
# Out:
# 2611

# %%
avg_playtime = df.groupby(['Game-title'],as_index = False).Playtime.mean()
avg_playtime['avg_playtime'] = avg_playtime['Playtime']
avg_playtime.drop(columns ='Playtime',inplace = True )

# %%
avg_playtime.head()
# Out:
#                                           Game-title  avg_playtime
# 0  1... 2... 3... KICK IT! (Drop That Beat Like a...          6.20
# 1                                    10 Second Ninja          5.40
# 2                                         10,000,000          3.60
# 3                                  100% Orange Juice         17.90
# 4                             12 Labours of Hercules          5.75

# %%
df = df.merge(avg_playtime, on='Game-title')

# %%
df.head()
# Out:
#    User-id   Game-title  Playtime    Genre  avg_playtime
# 0     5250  Alien Swarm       4.9  Shooter      9.311921
# 1   975449  Alien Swarm       9.8  Shooter      9.311921
# 2  1950243  Alien Swarm       3.8  Shooter      9.311921
# 3  2259650  Alien Swarm       3.2  Shooter      9.311921
# 4  2753525  Alien Swarm       3.2  Shooter      9.311921

# %%
def assign_rating(row):
    ratios = row['Playtime'] / row['avg_playtime']
    if ratios >= 0.8:
        return 5
    elif ratios >= 0.6:
        return 4
    elif ratios >= 0.4:
        return 3
    elif ratios >= 0.2:
        return 2
    else:
        return 1

# %%
df['personal-rating'] = df.apply(assign_rating, axis=1)

# %%
df
# Out:
#          User-id             Game-title  Playtime               Genre  \
# 0           5250            Alien Swarm       4.9             Shooter
# 1         975449            Alien Swarm       9.8             Shooter
# 2        1950243            Alien Swarm       3.8             Shooter
# 3        2259650            Alien Swarm       3.2             Shooter
# 4        2753525            Alien Swarm       3.2             Shooter
# ...          ...                    ...       ...                 ...
# 42534  287824954        Close Your Eyes       2.2              Puzzle
# 42535  293303005            All Is Dust       5.1  Role-playing (RPG)
# 42536  300248088       Sigils of Elohim     888.0              Puzzle
# 42537  306839937  Secret Files Tunguska       7.9     Point-and-click
# 42538  307846753          SimpleRockets      25.0           Simulator
#
#        avg_playtime  personal-rating
# 0          9.311921                3
# 1          9.311921                5
# 2          9.311921                3
# 3          9.311921                2
# 4          9.311921                2
# ...             ...              ...
# 42534      2.200000                5
# 42535      5.100000                5
# 42536    888.000000                5
# 42537      7.900000                5
# 42538     25.000000                5
#
# [42539 rows x 6 columns]

# %%
df.drop(columns=['Playtime', 'avg_playtime'], inplace=True)

# %%
df
# Out:
#          User-id             Game-title               Genre  personal-rating
# 0           5250            Alien Swarm             Shooter                3
# 1         975449            Alien Swarm             Shooter                5
# 2        1950243            Alien Swarm             Shooter                3
# 3        2259650            Alien Swarm             Shooter                2
# 4        2753525            Alien Swarm             Shooter                2
# ...          ...                    ...                 ...              ...
# 42534  287824954        Close Your Eyes              Puzzle                5
# 42535  293303005            All Is Dust  Role-playing (RPG)                5
# 42536  300248088       Sigils of Elohim              Puzzle                5
# 42537  306839937  Secret Files Tunguska     Point-and-click                5
# 42538  307846753          SimpleRockets           Simulator                5
#
# [42539 rows x 4 columns]

# %%
df.to_csv("Data_final.csv", index=False)
